# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

# %%
## OBTENEMOS TODA LA INFORMACIÓN DE LOS DIFERENTES CSV.
nivel_educativo = pd.read_csv('fiuba_1_postulantes_educacion.csv')
nacimiento_genero = pd.read_csv('fiuba_2_postulantes_genero_y_edad.csv')
vistas_avisos = pd.read_csv('fiuba_3_vistas.csv')
postulaciones = pd.read_csv('fiuba_4_postulaciones.csv')
avisos_online = pd.read_csv('fiuba_5_avisos_online.csv')
avisos_detalle = pd.read_csv('fiuba_6_avisos_detalle.csv')

# %%
nivel_educativo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298231 entries, 0 to 298230
# Data columns (total 3 columns):
# idpostulante    298231 non-null object
# nombre          298231 non-null object
# estado          298231 non-null object
# dtypes: object(3)
# memory usage: 6.8+ MB

# %%
nivel_educativo.head()
# Out:
#   idpostulante         nombre    estado
# 0         NdJl       Posgrado  En Curso
# 1         8BkL  Universitario  En Curso
# 2         1d2B  Universitario  En Curso
# 3         NPBx  Universitario  En Curso
# 4         NPBx         Master  En Curso

# %%
nacimiento_genero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200888 entries, 0 to 200887
# Data columns (total 3 columns):
# idpostulante       200888 non-null object
# fechanacimiento    196138 non-null object
# sexo               200888 non-null object
# dtypes: object(3)
# memory usage: 4.6+ MB

# %%
nacimiento_genero.head()
# Out:
#   idpostulante fechanacimiento  sexo
# 0         NM5M      1970-12-03   FEM
# 1         5awk      1962-12-04   FEM
# 2         ZaO5      1978-08-10   FEM
# 3         NdJl      1969-05-09  MASC
# 4         eo2p      1981-02-16  MASC

# %%
vistas_avisos.info()
vistas_avisos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961897 entries, 0 to 961896
# Data columns (total 3 columns):
# idAviso         961897 non-null int64
# timestamp       961897 non-null object
# idpostulante    961897 non-null object
# dtypes: int64(1), object(2)
# memory usage: 22.0+ MB
#       idAviso                     timestamp idpostulante
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP

# %%
postulaciones.info()
postulaciones.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401623 entries, 0 to 3401622
# Data columns (total 3 columns):
# idaviso             int64
# idpostulante        object
# fechapostulacion    object
# dtypes: int64(1), object(2)
# memory usage: 77.9+ MB
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
avisos_online.info()
avisos_online.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5028 entries, 0 to 5027
# Data columns (total 1 columns):
# idaviso    5028 non-null int64
# dtypes: int64(1)
# memory usage: 39.4 KB
#       idaviso
# 0  1112355872
# 1  1112335374
# 2  1112374842
# 3  1111984070
# 4  1111822480

# %%
avisos_detalle.info()
avisos_detalle.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13534 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13534 non-null int64
# idpais                  13534 non-null int64
# titulo                  13534 non-null object
# descripcion             13534 non-null object
# nombre_zona             13534 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13534 non-null object
# nivel_laboral           13534 non-null object
# nombre_area             13534 non-null object
# denominacion_empresa    13529 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa
# 0                   VENTOR
# 1  Farmacias Central Oeste
# 2              FAMITAX SRL
# 3      Wurth Argentina S.A
# 4       ELECTRO OUTLET SRL

# %%
#avisos_detalle['ciudad'].value_counts()
#avisos_detalle['tipo_de_trabajo'].value_counts()
#avisos_detalle['titulo'].value_counts()
avisos_detalle['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires              12654
# Capital Federal                  876
# GBA Oeste                          2
# Buenos Aires (fuera de GBA)        2
# Name: nombre_zona, dtype: int64

# %%
postulantes = nivel_educativo.merge(nacimiento_genero,left_on='idpostulante', right_on='idpostulante',how='outer')

# %%
postulantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310367 entries, 0 to 310366
# Data columns (total 5 columns):
# idpostulante       310367 non-null object
# nombre             298231 non-null object
# estado             298231 non-null object
# fechanacimiento    304928 non-null object
# sexo               310367 non-null object
# dtypes: object(5)
# memory usage: 14.2+ MB

# %%
postulantes['sexo'].value_counts()
postulantes.duplicated
# Out:
# <bound method DataFrame.duplicated of        idpostulante             nombre      estado fechanacimiento        sexo
# 0              NdJl           Posgrado    En Curso      1969-05-09        MASC
# 1              NdJl      Universitario    Graduado      1969-05-09        MASC
# 2              8BkL      Universitario    En Curso      1976-07-21         FEM
# 3              8BkL      Universitario    Graduado      1976-07-21         FEM
# 4              8BkL           Posgrado    Graduado      1976-07-21         FEM
# 5              8BkL             Master    Graduado      1976-07-21         FEM
# 6              1d2B      Universitario    En Curso      1976-02-28        MASC
# 7              NPBx      Universitario    En Curso      1981-03-09        MASC
# 8              NPBx             Master    En Curso      1981-03-09        MASC
# 9              NPBx      Universitario    Graduado      1981-03-09        MASC
# 10             Ym2X               Otro    En Curso      1964-01-19        MASC
# 11             Ym2X      Universitario    Graduado      1964-01-19        MASC
# 12             ZKl5             Master    En Curso      1974-05-06        MASC
# 13             ZKl5      Universitario    Graduado      1974-05-06        MASC
# 14            EDD99  Terciario/Técnico    En Curso      1966-03-01         FEM
# 15            EDD99      Universitario    Graduado      1966-03-01         FEM
# 16            Y043Z      Universitario    En Curso      1979-03-24        MASC
# 17            Y043Z  Terciario/Técnico    Graduado      1979-03-24        MASC
# 18            6M3jr      Universitario    En Curso      1975-11-03        MASC
# 19            EpDDJ      Universitario    En Curso      1961-11-28        MASC
# 20            abpEZ               Otro    En Curso      1977-08-30        MASC
# 21            abpEZ      Universitario    Graduado      1977-08-30        MASC
# 22            EZD29      Universitario    En Curso      1974-12-12        MASC
# 23            EZD29  Terciario/Técnico    En Curso      1974-12-12        MASC
# 24            EZD29               Otro    En Curso      1974-12-12        MASC
# 25            EZD29  Terciario/Técnico    Graduado      1974-12-12        MASC
# 26            EZD29      Universitario    Graduado      1974-12-12        MASC
# 27            EZD29           Posgrado    Graduado      1974-12-12        MASC
# 28            EZD29               Otro    Graduado      1974-12-12        MASC
# 29            EZD29      Universitario  Abandonado      1974-12-12        MASC
# ...             ...                ...         ...             ...         ...
# 310337      wVkMkMl                NaN         NaN      1990-08-17         FEM
# 310338      3NP0PBr                NaN         NaN      1984-03-31         FEM
# 310339      JBrNr05                NaN         NaN      1980-07-10        MASC
# 310340      EzemeQ4                NaN         NaN      1999-12-11         FEM
# 310341      5mPJPjq                NaN         NaN      1976-05-16        MASC
# 310342      LNKpKqq                NaN         NaN      1968-03-30        MASC
# 310343      rmdlBzz                NaN         NaN      1983-04-19         FEM
# 310344      JBrNMOp                NaN         NaN      1997-09-07         FEM
# 310345      96XvA9w                NaN         NaN      1998-06-19         FEM
# 310346      bOjXw42                NaN         NaN      1974-12-14         FEM
# 310347      2zP6Jro                NaN         NaN      1994-08-21         FEM
# 310348      4rPb9rM                NaN         NaN      1999-04-14        MASC
# 310349      dYj4qYD                NaN         NaN      1983-03-25         FEM
# 310350      ekOwaZ9                NaN         NaN      1990-12-15        MASC
# 310351      ekOwarj                NaN         NaN      1989-08-14        MASC
# 310352      RzrQvqx                NaN         NaN             NaN  NO_DECLARA
# 310353      Bm5w9ZE                NaN         NaN      1996-11-21         FEM
# 310354      lDLj9L6                NaN         NaN             NaN  NO_DECLARA
# 310355      RzrQvvR                NaN         NaN             NaN  NO_DECLARA
# 310356      vVja4Rj                NaN         NaN      1987-04-26         FEM
# 310357      OqrlEVx                NaN         NaN      1998-09-04        MASC
# 310358      6rPEvoL                NaN         NaN             NaN  NO_DECLARA
# 310359      vVja48E                NaN         NaN      1977-04-06         FEM
# 310360      akjVl35                NaN         NaN      1990-08-25         FEM
# 310361      X95JX3Q                NaN         NaN             NaN  NO_DECLARA
# 310362      mzdNo99                NaN         NaN      1999-08-10         FEM
# 310363      Nzr1J34                NaN         NaN             NaN  NO_DECLARA
# 310364      JBrNMNk                NaN         NaN      1997-01-11        MASC
# 310365      2zP6Jd0                NaN         NaN      1997-03-06         FEM
# 310366      2zP6J9V                NaN         NaN             NaN  NO_DECLARA
#
# [310367 rows x 5 columns]>

# %%
nacimiento_genero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200888 entries, 0 to 200887
# Data columns (total 3 columns):
# idpostulante       200888 non-null object
# fechanacimiento    196138 non-null object
# sexo               200888 non-null object
# dtypes: object(3)
# memory usage: 4.6+ MB

# %%
nacimiento_genero['sexo'].value_counts()
# Out:
# FEM           101981
# MASC           94339
# NO_DECLARA      4568
# Name: sexo, dtype: int64

# %%
ids = postulantes["idpostulante"]
postulantes[ids.isin(ids[ids.duplicated()])]
# Out:
#        idpostulante             nombre      estado fechanacimiento  sexo
# 0              NdJl           Posgrado    En Curso      1969-05-09  MASC
# 1              NdJl      Universitario    Graduado      1969-05-09  MASC
# 2              8BkL      Universitario    En Curso      1976-07-21   FEM
# 3              8BkL      Universitario    Graduado      1976-07-21   FEM
# 4              8BkL           Posgrado    Graduado      1976-07-21   FEM
# 5              8BkL             Master    Graduado      1976-07-21   FEM
# 7              NPBx      Universitario    En Curso      1981-03-09  MASC
# 8              NPBx             Master    En Curso      1981-03-09  MASC
# 9              NPBx      Universitario    Graduado      1981-03-09  MASC
# 10             Ym2X               Otro    En Curso      1964-01-19  MASC
# 11             Ym2X      Universitario    Graduado      1964-01-19  MASC
# 12             ZKl5             Master    En Curso      1974-05-06  MASC
# 13             ZKl5      Universitario    Graduado      1974-05-06  MASC
# 14            EDD99  Terciario/Técnico    En Curso      1966-03-01   FEM
# 15            EDD99      Universitario    Graduado      1966-03-01   FEM
# 16            Y043Z      Universitario    En Curso      1979-03-24  MASC
# 17            Y043Z  Terciario/Técnico    Graduado      1979-03-24  MASC
# 20            abpEZ               Otro    En Curso      1977-08-30  MASC
# 21            abpEZ      Universitario    Graduado      1977-08-30  MASC
# 22            EZD29      Universitario    En Curso      1974-12-12  MASC
# 23            EZD29  Terciario/Técnico    En Curso      1974-12-12  MASC
# 24            EZD29               Otro    En Curso      1974-12-12  MASC
# 25            EZD29  Terciario/Técnico    Graduado      1974-12-12  MASC
# 26            EZD29      Universitario    Graduado      1974-12-12  MASC
# 27            EZD29           Posgrado    Graduado      1974-12-12  MASC
# 28            EZD29               Otro    Graduado      1974-12-12  MASC
# 29            EZD29      Universitario  Abandonado      1974-12-12  MASC
# 30            YrkoJ             Master    En Curso      1977-11-06  MASC
# 31            YrkoJ      Universitario    Graduado      1977-11-06  MASC
# 32            YrkoJ           Posgrado    Graduado      1977-11-06  MASC
# ...             ...                ...         ...             ...   ...
# 297992      Bm5wBPR         Secundario    Graduado      1976-12-15   FEM
# 297993      Bm5wBPR      Universitario    Graduado      1976-12-15   FEM
# 298002      zvabadK      Universitario    Graduado      1993-01-05   FEM
# 298003      zvabadK  Terciario/Técnico    Graduado      1993-01-05   FEM
# 298013      lDLjLG6         Secundario    Graduado      1989-09-19   FEM
# 298014      lDLjLG6      Universitario    Graduado      1989-09-19   FEM
# 298015      lDLjLG6      Universitario  Abandonado      1989-09-19   FEM
# 298021      DrXeX4K               Otro    Graduado      1981-01-25   FEM
# 298022      DrXeX4K         Secundario    Graduado      1981-01-25   FEM
# 298023      DrXeX4K      Universitario  Abandonado      1981-01-25   FEM
# 298035      JBrNr8r           Posgrado    Graduado      1992-12-10   FEM
# 298036      JBrNr8r      Universitario    Graduado      1992-12-10   FEM
# 298037      bOjXjbV         Secundario    Graduado      1993-11-18  MASC
# 298038      bOjXjbV  Terciario/Técnico    Graduado      1993-11-18  MASC
# 298039      bOjXjbV               Otro    Graduado      1993-11-18  MASC
# 298042      A3X4Xxm         Secundario    Graduado      1996-05-14  MASC
# 298043      A3X4Xxm      Universitario  Abandonado      1996-05-14  MASC
# 298045      QNrBr5l         Secundario    Graduado      1989-02-26   FEM
# 298046      QNrBr5l      Universitario    Graduado      1989-02-26   FEM
# 298079      VNr0DvD  Terciario/Técnico    Graduado      1975-05-20   FEM
# 298080      VNr0DvD         Secundario    Graduado      1975-05-20   FEM
# 298082      xkd652a      Universitario    Graduado      1994-11-11  MASC
# 298083      xkd652a         Secundario    Graduado      1994-11-11  MASC
# 298087      pzdkx4b      Universitario    Graduado      1994-07-02  MASC
# 298088      pzdkx4b         Secundario    Graduado      1994-07-02  MASC
# 298101      GNZqAKN         Secundario    Graduado      1993-03-12  MASC
# 298102      GNZqAKN      Universitario    Graduado      1993-03-12  MASC
# 298109      vVja45X         Secundario    Graduado      1996-04-26  MASC
# 298110      vVja45X  Terciario/Técnico    Graduado      1996-04-26  MASC
# 298111      vVja45X      Universitario  Abandonado      1996-04-26  MASC
#
# [189755 rows x 5 columns]

# %%
#postulantes['fechanacimiento'] = pd.to_datetime(postulantes['fechanacimiento'], errors = 'coerce')
postulantes['tamañoFecha'] = postulantes['fechanacimiento'].str.len()

# %%
postulantes['tamañoFecha'].value_counts()
# Out:
# 10.0    304928
# Name: tamañoFecha, dtype: int64

# %%
postulantes['fechanacimiento'] = pd.to_datetime(postulantes['fechanacimiento'], errors = 'coerce')

# %%
postulantes['fechanacimiento'].value_counts()
# Out:
# 1994-05-24    103
# 1991-06-20    100
# 1993-03-18     98
# 1990-10-19     95
# 1992-08-20     91
# 1993-12-27     90
# 1991-10-09     90
# 1994-04-08     88
# 1992-12-09     87
# 1993-09-15     87
# 1992-01-06     87
# 1994-04-19     86
# 1993-12-28     86
# 1991-06-04     85
# 1992-05-05     85
# 1993-03-22     85
# 1991-05-13     85
# 1993-09-10     84
# 1990-07-07     84
# 1992-04-13     84
# 1989-12-12     84
# 1993-05-28     84
# 1994-04-14     84
# 1990-08-10     84
# 1991-09-19     83
# 1988-12-19     82
# 1992-10-19     81
# 1994-03-25     81
# 1992-01-10     81
# 1993-03-04     81
#              ...
# 1953-06-05      1
# 1958-01-05      1
# 1960-03-29      1
# 1960-09-09      1
# 1964-08-11      1
# 1957-10-31      1
# 1964-05-27      1
# 1959-08-01      1
# 1967-05-11      1
# 1959-11-21      1
# 1965-10-15      1
# 1970-02-23      1
# 1961-01-05      1
# 1955-12-02      1
# 1965-03-14      1
# 1974-03-09      1
# 1973-02-26      1
# 1961-12-08      1
# 1950-10-04      1
# 1965-02-11      1
# 1956-11-01      1
# 1959-04-21      1
# 1968-06-08      1
# 1961-09-22      1
# 1958-02-15      1
# 1957-07-15      1
# 1963-05-15      1
# 1959-01-24      1
# 1955-11-14      1
# 1963-12-17      1
# Name: fechanacimiento, Length: 15020, dtype: int64

# %%
## VAMOS A CALCULAR LA EDAD PARA LOS POSTULANTES.
import datetime as DT
now = pd.Timestamp(DT.datetime.now())
postulantes['edad'] = (now - postulantes['fechanacimiento']).astype('<m8[Y]')

# %%
postulantes.head()
# Out:
#   idpostulante         nombre    estado fechanacimiento  sexo  tamañoFecha  \
# 0         NdJl       Posgrado  En Curso      1969-05-09  MASC         10.0
# 1         NdJl  Universitario  Graduado      1969-05-09  MASC         10.0
# 2         8BkL  Universitario  En Curso      1976-07-21   FEM         10.0
# 3         8BkL  Universitario  Graduado      1976-07-21   FEM         10.0
# 4         8BkL       Posgrado  Graduado      1976-07-21   FEM         10.0
#
#    edad
# 0  48.0
# 1  48.0
# 2  41.0
# 3  41.0
# 4  41.0

# %%
## hacemos un primer chequeo sobre la edad.-
postulantes['edad'].value_counts()
# Out:
# 26.0     19618
# 25.0     19171
# 24.0     19030
# 27.0     18809
# 23.0     18109
# 22.0     16639
# 28.0     16206
# 29.0     15447
# 21.0     14609
# 30.0     13430
# 31.0     12575
# 20.0     11333
# 32.0     10998
# 33.0      9480
# 34.0      8686
# 35.0      7843
# 19.0      7792
# 36.0      7482
# 37.0      6576
# 38.0      6047
# 39.0      5381
# 40.0      4623
# 41.0      3951
# 42.0      3556
# 43.0      3308
# 18.0      3212
# 44.0      2570
# 45.0      2236
# 46.0      2180
# 47.0      1915
#          ...
# 52.0       980
# 53.0       919
# 54.0       852
# 55.0       688
# 56.0       682
# 57.0       558
# 58.0       417
# 59.0       349
# 61.0       264
# 60.0       230
# 62.0       164
# 17.0       159
# 63.0       101
# 64.0        64
# 67.0        43
# 65.0        32
# 66.0        27
# 68.0        22
# 70.0        13
# 69.0        10
# 75.0         5
# 71.0         5
# 76.0         2
# 73.0         2
# 74.0         1
# 96.0         1
# 242.0        1
# 12.0         1
# 78.0         1
# 100.0        1
# Name: edad, Length: 64, dtype: int64

# %%
postulantes['nombre'].value_counts()
postulantes['estado'].value_counts()
# Out:
# Graduado      194474
# En Curso       78531
# Abandonado     25226
# Name: estado, dtype: int64

# %%
## EJEMPLO DE FILTRO MÚLTIPLE: (df['col1'] >= 1) & (df['col1'] <=1 )
postulantes = postulantes[(postulantes['edad'] > 17) & (postulantes['edad'] < 100)]

# %%
## EN POSTULANTES TENEMOS EN PRIMER INSTANCIA LOS DATOS COMBINADOS TANTO DE LA ESPECIALIZACIÓN DE CADA POSTULANTE
## COMO ASÍ TAMBIÉN SU SEXO, FECHA DE NACIMIENTO Y SU EDAD, POR OTRO LADO HEMOS DECIDIDO FILTRAR POR AQUELLOS 
## VALORES QUE INDICAN UNA EDAD DENTRO DE LOS VALORES ACEPTADO (CRITERIO/ETICA PERSONAL EN ÚLTIMA INSTANCIA)
postulantes
## agrupados = postulantes.groupby(postulantes['nombre'])
## agrupados['nombre'].value_counts()
## areazona = pd.DataFrame([avisos_online[avisos_online['nombre_area'] == 'Ventas']['nombre_zona'].value_counts()])

estudiosCompletos =  pd.DataFrame([postulantes[postulantes['estado'] == 'Graduado']['nombre'].value_counts()])
estudiosIncompletos =  pd.DataFrame([postulantes[postulantes['estado'] == 'Ventas']['nombre'].value_counts()])

# %%
estudiosCompletos
# Out:
#         Secundario  Universitario  Terciario/Técnico   Otro  Posgrado  Master  \
# nombre      101546          38247              26730  18754      4801    1922
#
#         Doctorado
# nombre        105

# %%
## hacemos un primer chequeo sobre la edad.-
postulantes['edad'].value_counts()
# Out:
# 26.0    19618
# 25.0    19171
# 24.0    19030
# 27.0    18809
# 23.0    18109
# 22.0    16639
# 28.0    16206
# 29.0    15447
# 21.0    14609
# 30.0    13430
# 31.0    12575
# 20.0    11333
# 32.0    10998
# 33.0     9480
# 34.0     8686
# 35.0     7843
# 19.0     7792
# 36.0     7482
# 37.0     6576
# 38.0     6047
# 39.0     5381
# 40.0     4623
# 41.0     3951
# 42.0     3556
# 43.0     3308
# 18.0     3212
# 44.0     2570
# 45.0     2236
# 46.0     2180
# 47.0     1915
# 48.0     1652
# 49.0     1433
# 50.0     1254
# 51.0     1176
# 52.0      980
# 53.0      919
# 54.0      852
# 55.0      688
# 56.0      682
# 57.0      558
# 58.0      417
# 59.0      349
# 61.0      264
# 60.0      230
# 62.0      164
# 63.0      101
# 64.0       64
# 67.0       43
# 65.0       32
# 66.0       27
# 68.0       22
# 70.0       13
# 69.0       10
# 71.0        5
# 75.0        5
# 73.0        2
# 76.0        2
# 74.0        1
# 96.0        1
# 78.0        1
# Name: edad, dtype: int64

# %%
avisos_detalle['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires              12654
# Capital Federal                  876
# GBA Oeste                          2
# Buenos Aires (fuera de GBA)        2
# Name: nombre_zona, dtype: int64

# %%
## POR TENER SOLO 2 REGISTROS QUE DOS SON DE FUERA DE GBA, LOS OMITIMOS.
## PUESTO QUE NO GENERA INFORMACIÓN DE VALOR EN RELACIÓN A LA CANTIDAD DE DATOS.
avisos_detalle = avisos_detalle[(avisos_detalle['nombre_zona'] != 'Buenos Aires (fuera de GBA)')]

# %%
avisos_detalle['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires    12654
# Capital Federal        876
# GBA Oeste                2
# Name: nombre_zona, dtype: int64

# %%
## Pasamos los dos de zona oeste al de gran buenos aires.
avisos_detalle.loc[avisos_detalle.nombre_zona == 'GBA Oeste', 'nombre_zona'] = 'Gran Buenos Aires'
avisos_detalle['nombre_zona'].value_counts()
# Out:
# Gran Buenos Aires    12656
# Capital Federal        876
# Name: nombre_zona, dtype: int64

# %%
avisos_detalle['tipo_de_trabajo'].value_counts()
# Out:
# Full-time          12337
# Part-time            863
# Teletrabajo          110
# Pasantia              63
# Por Horas             63
# Temporario            42
# Por Contrato          37
# Fines de Semana       14
# Primer empleo          3
# Name: tipo_de_trabajo, dtype: int64

# %%
avisos_detalle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
avisos_detalle['nivel_laboral'].value_counts()
# Out:
# Senior / Semi-Senior                    9407
# Junior                                  2216
# Otro                                     919
# Jefe / Supervisor / Responsable          809
# Gerencia / Alta Gerencia / Dirección     181
# Name: nivel_laboral, dtype: int64

# %%
## VAMOS A BUSCARA LOS RANGOS DE EDAD QUE INCLUYAN QUE INTEGRAN MAS POSTULANTES.
postulantes.head()
postulantes['rango_edad'] = 'abc'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
postulantes.loc[postulantes.edad < 20, 'rango_edad'] = '<20'
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
postulantes['rango_edad'].value_counts()
# Out:
# abc    293755
# <20     11004
# Name: rango_edad, dtype: int64

# %%
postulantes.loc[postulantes.edad < 20, 'rango_edad'] = '< 20'
postulantes.loc[postulantes.edad > 65, 'rango_edad'] = '> 65'
postulantes.loc[postulantes.rango_edad == 'abc', 'rango_edad'] = '> 65'
postulantes.loc[(postulantes.edad >= 20) & (postulantes.edad <= 24), 'rango_edad'] = '20 ~ 25'
postulantes.loc[(postulantes.edad >= 25) & (postulantes.edad <= 29), 'rango_edad'] = '25 ~ 30'
postulantes.loc[(postulantes.edad >= 30) & (postulantes.edad <= 34), 'rango_edad'] = '30 ~ 35'
postulantes.loc[(postulantes.edad >= 35) & (postulantes.edad <= 39), 'rango_edad'] = '35 ~ 40'
postulantes.loc[(postulantes.edad >= 40) & (postulantes.edad <= 44), 'rango_edad'] = '40 ~ 45'
postulantes.loc[(postulantes.edad >= 45) & (postulantes.edad <= 49), 'rango_edad'] = '45 ~ 50'
postulantes.loc[(postulantes.edad >= 50) & (postulantes.edad <= 54), 'rango_edad'] = '50 ~ 55'
postulantes.loc[(postulantes.edad >= 55) & (postulantes.edad <= 59), 'rango_edad'] = '55 ~ 60'
postulantes.loc[(postulantes.edad >= 60) & (postulantes.edad <= 64), 'rango_edad'] = '60 ~ 65'

# %%
# PODEMOS LISTAR CUALES SON LOS RANGOS MÁS SIGNIFICATIVOS SOBRE LAS EDADES DE LOS POSTULANTES.
# QUIENES SE REGISTRAN EN EL SITIO EN CUESTIÓN.
rangos_edad = postulantes['rango_edad'].value_counts()
rangos_edad
# Out:
# 25 ~ 30    89251
# 20 ~ 25    79720
# 30 ~ 35    55169
# 35 ~ 40    33329
# 40 ~ 45    18008
# < 20       11004
# 45 ~ 50     9416
# 50 ~ 55     5181
# 55 ~ 60     2694
# 60 ~ 65      823
# > 65         164
# Name: rango_edad, dtype: int64

# %%
# A CONTINUACIÓN GRAFICAMOS LOS RANGOS DE EDAD:
# CONSIDEREMOS QUE CONTIENE REPETIDOS PUESTO 
# QUE UNA PERSONA INCLUYE VARIOS NIVELES EDUCATIVOS.
g = sns.barplot(x=rangos_edad.values, y=rangos_edad.index, orient='h') 
g.set_title("Usuarios por Rango de Edad", fontsize=15)
g.set_xlabel("Cantidad de Usuarios", fontsize=12)
g.set_ylabel("Rangos de Edad", fontsize=12)
# Out:
# Text(0,0.5,'Rangos de Edad')

# %%
postulantes.loc[postulantes.nombre == 'Terciario/Técnico', 'nombre'] = 'Terciario'
postulantes.loc[postulantes.nombre == 'Terciario/Tecnico', 'nombre'] = 'Terciario'

# %%
# A CONTINUACIÓN GRAFICAMOS LOS DIFERENTES NIVELES EDUCATIVOS DE LOS USUARIOS.
g = sns.countplot(x="nombre", hue="estado", data=postulantes, palette="hls")
g.set_title("Niveles educativos de los usuarios", fontsize=18)
g.set_xlabel("Estudios", fontsize=18)
g.set_ylabel("Cantidad de Usuarios", fontsize=18)
# Out:
# Text(0,0.5,'Cantidad de Usuarios')

# %%
pd.crosstab(postulantes.nombre, postulantes.estado)
# Out:
# estado         Abandonado  En Curso  Graduado
# nombre
# Doctorado              15        91       105
# Master                144      1511      1922
# Otro                  942      4891     18754
# Posgrado              315      2228      4801
# Secundario           3082      3850    101546
# Terciario            5640     14858     26730
# Universitario       14811     50038     38247

# %%
postulantes.head()
# Out:
#   idpostulante         nombre    estado fechanacimiento  sexo  tamañoFecha  \
# 0         NdJl       Posgrado  En Curso      1969-05-09  MASC         10.0
# 1         NdJl  Universitario  Graduado      1969-05-09  MASC         10.0
# 2         8BkL  Universitario  En Curso      1976-07-21   FEM         10.0
# 3         8BkL  Universitario  Graduado      1976-07-21   FEM         10.0
# 4         8BkL       Posgrado  Graduado      1976-07-21   FEM         10.0
#
#    edad rango_edad
# 0  48.0    45 ~ 50
# 1  48.0    45 ~ 50
# 2  41.0    40 ~ 45
# 3  41.0    40 ~ 45
# 4  41.0    40 ~ 45

# %%
## COMO SABEMOS TENEMOS DUPLICADOS, PRODUCTO DE LOS VARIOS TIPOS DE ESTUDIO QUE UNA 
## PERSONA PUDO HABER REALIZADO Y QUE SE INCLUYEN EN LA INFORMACIÓN DADA.
postulantes_unicos = postulantes.drop_duplicates(subset="idpostulante", keep='first', inplace=False)

# %%
postulantes_unicos.head()
# Out:
#    idpostulante         nombre    estado fechanacimiento  sexo  tamañoFecha  \
# 0          NdJl       Posgrado  En Curso      1969-05-09  MASC         10.0
# 2          8BkL  Universitario  En Curso      1976-07-21   FEM         10.0
# 6          1d2B  Universitario  En Curso      1976-02-28  MASC         10.0
# 7          NPBx  Universitario  En Curso      1981-03-09  MASC         10.0
# 10         Ym2X           Otro  En Curso      1964-01-19  MASC         10.0
#
#     edad rango_edad
# 0   48.0    45 ~ 50
# 2   41.0    40 ~ 45
# 6   42.0    40 ~ 45
# 7   37.0    35 ~ 40
# 10  54.0    50 ~ 55

# %%
## AHORA MOSTRAMOS LOS RANGOS DE EDAD SIN TENER POSTULANTES REPETIDOS.
rangos_edad = postulantes_unicos['rango_edad'].value_counts()
g = sns.barplot(x=rangos_edad.values, y=rangos_edad.index, orient='h')
g.set_title("Usuarios por Rango de Edad", fontsize=15)
g.set_xlabel("Cantidad de Usuarios", fontsize=12)
g.set_ylabel("Rangos de Edad", fontsize=12)
# Out:
# Text(0,0.5,'Rangos de Edad')

# %%
avisos_online.info()
avisos_online.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5028 entries, 0 to 5027
# Data columns (total 1 columns):
# idaviso    5028 non-null int64
# dtypes: int64(1)
# memory usage: 39.4 KB
#       idaviso
# 0  1112355872
# 1  1112335374
# 2  1112374842
# 3  1111984070
# 4  1111822480

# %%
avisos_online['esta_online'] = 'si'

# %%
avisos_online.head()
# Out:
#       idaviso esta_online
# 0  1112355872          si
# 1  1112335374          si
# 2  1112374842          si
# 3  1111984070          si
# 4  1111822480          si

# %%
avisos_detalle.info()
avisos_detalle.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa
# 0                   VENTOR
# 1  Farmacias Central Oeste
# 2              FAMITAX SRL
# 3      Wurth Argentina S.A
# 4       ELECTRO OUTLET SRL

# %%
avisos_detalle_completo = avisos_detalle.merge(avisos_online,left_on='idaviso', right_on='idaviso',how='left')
avisos_detalle_completo
# Out:
#           idaviso  idpais                                             titulo  \
# 0         8725750       1                   VENDEDOR/A PROVINCIA DE SANTA FE
# 1        17903700       1                                         Enfermeras
# 2      1000150677       1                                     Chofer de taxi
# 3      1000610287       1      CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4      1000872556       1      Operarios de Planta - Rubro Electrodomésticos
# 5      1001135716       1      Vendedor Viajante TUCUMAN/SANTIAGO DEL ESTERO
# 6      1001326344       1           Vendedor Viajante RECONQUISTA/AVELLANEDA
# 7      1001455648       1            Vendedor Viajante PILAR / ESCOBAR/TIGRE
# 8         9240880       1  Productores Asesores Independiente, para venta...
# 9      1001202662       1                              promotor/a , asesor/a
# 10     1001724563       1                                         Paramédico
# 11     1002181678       1                 Vendedor Viajante TIERRA DEL FUEGO
# 12     1002308544       1   Preventistas Importante Distribuidora de Bebidas
# 13     1002377536       1  Personal con experiencia en lavandería  para H...
# 14     1002448818       1                           Ejecutivo de Cuentas Sr.
# 15     1002511855       1                                Ingeniero Electrico
# 16     1110319893       1                Vendedores Telefónicos (Part- time)
# 17     1110383223       1  Vendedor Viajante ADROGUE/LANUS/AVELLANEDA/LOM...
# 18     1110386791       1                        Analista de Demand Planning
# 19     1110185164       1                        Administrativo de Recepción
# 20     1110322236       1                                  Analista Contable
# 21     1110513885       1    Distribuidor domiciliario con moto (SAN MIGUEL)
# 22     1110322853       1            OPERADOR para Centro Operaciones de Red
# 23     1110640369       1                     VENDEDORES DE PLANES DE AHORRO
# 24     1110640622       1  Agente Inmobiliario para Oficinas RE/MAX en Zo...
# 25     1110706074       1         TECNICO SSr.  -Soporte a usuarios nivel 2-
# 26     1110711023       1   ENVASADOR / PREPARADOR / CONTROLADOR / EMBALADOR
# 27     1110715814       1                      Jefe de Calidad con movilidad
# 28     1110843329       1                                Chofer para Reparto
# 29     1110906170       1         SUPERVISOR COMODORO RIVADAVIA/BAHIA BLANCA
# ...           ...     ...                                                ...
# 13502  1112342117       1         Programador C# .NET Sr. // Zona Tribunales
# 13503  1112342134       1                   Electricista para Barrio Cerrado
# 13504  1112342203       1              Analista en Sistemas y Desarrollo Web
# 13505  1112342204       1  Ejecutivo de Ventas - Prov. de Bs. As e Interi...
# 13506  1112342210       1                                 Licenciado en RRHH
# 13507  1112342213       1                        Programadores Oracle PL/SQL
# 13508  1112342246       1                    Analista Funcional - zona Pilar
# 13509  1112342264       1  Analista de liquidación de Sueldos Senior  Co...
# 13510  1112342289       1     Ingeniero Ssr para logística interna de partes
# 13511  1112342347       1  Operario con exp. en Inyección plástica Z/ Lom...
# 13512  1112342374       1                   REPOSITOR EXTERNO (BAHIA BLANCA)
# 13513  1112342384       1  PROMOVENDEDORAS (ZONAS: Retiro, Aeroparque y T...
# 13514  1112342389       1  Coordinador de Contrataciones de Transporte Te...
# 13515  1112342090       1  Desarrolladores .NET C# nivel Jr. / de 6 a 18 ...
# 13516  1112342190       1  ANALISTA CONTABLE IMPOSITIVO para Área de Admi...
# 13517  1112342215       1      HELP DESK ANALYST (Inglés, part time 4 horas)
# 13518  1112342288       1     INGENIERO MECANICO, ELECTROMECANICO y/o CIVIL
# 13519  1112341862       1  24 Feb - Chief Software Architect ($100K/yr) -...
# 13520  1112341899       1  24 Feb - Customer Support Manager ($100K/yr) -...
# 13521  1112341992       1  24 Feb - VP of Customer Support ($200K/yr) - O...
# 13522  1112342193       1                        Supervisor de Mantenimiento
# 13523  1112342444       1  Vendedor Telefónico / Telemarketer / Call Center
# 13524  1112342462       1               Analista de Comercio Exterior(Pilar)
# 13525  1112342487       1  Técnico para operación y detección en equipos ...
# 13526  1112342500       1                RESPONSABLE DE DISEÑO Y DESARROLLO
# 13527  1112342505       1                      Vendedor de Salon -- UNOMOTOS
# 13528  1112342513       1                OPERADOR DE ENSAYOS NO DESTRUCTIVOS
# 13529  1112342456       1  Back officer Junior de Fondos Comunes de Inver...
# 13530  1112342496       1                           Asistente Administrativo
# 13531  1112342432       1  Ingeniero para coordinación de obras de canali...
#
#                                              descripcion        nombre_zona  \
# 0      <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1      <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2      <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3      <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4      <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
# 5      <p>Somos una empresa multinacional que opera e...  Gran Buenos Aires
# 6      <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 7      <p>Somos una empresa multinacional que opera e...  Gran Buenos Aires
# 8      Agente\r\noficial Selecciona:</span></strong><...    Capital Federal
# 9      <p>En Cerantola nos encontramos en la busqueda...  Gran Buenos Aires
# 10     <p>Nos encontramos en un proceso de selección ...  Gran Buenos Aires
# 11     <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 12     <p>YAMANIL S-A . se encuentra en busqueda de p...  Gran Buenos Aires
# 13     <p><strong><span lang="ES">Adecco Hoteles y Ca...  Gran Buenos Aires
# 14     <p>Importante empresa del Mercado Asegurador A...  Gran Buenos Aires
# 15     <p>Nos encontramos en búsqueda de un  Ingenier...  Gran Buenos Aires
# 16     <p><strong>Estamos en busqueda de representant...  Gran Buenos Aires
# 17     <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 18     <p>SC Johnson, empresa líder mundial en fabric...  Gran Buenos Aires
# 19     <p>Centro Médico Accord se encuentra en la bús...  Gran Buenos Aires
# 20     <p>Nos encontramos en la búsqueda de un Analis...  Gran Buenos Aires
# 21     <p>Importante correo privado ubicado en SAN MI...  Gran Buenos Aires
# 22     <p><strong>Express se encuentra en la búsqueda...  Gran Buenos Aires
# 23     <p style="">Concesionario Oficial Renault Nº1 ...  Gran Buenos Aires
# 24     <p>Si te gusta deleitar a tus clientes, brinda...    Capital Federal
# 25     <p style=""><span style="">Somos una empresa a...  Gran Buenos Aires
# 26     <p><strong>Descripción del aviso de empleo:</s...  Gran Buenos Aires
# 27     <p>Somos una empresa 100% argentina que se esp...  Gran Buenos Aires
# 28     <p>Nos encontramos en la busqueda de chofer  d...  Gran Buenos Aires
# 29     <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# ...                                                  ...                ...
# 13502  <p><strong>SOLUTIX</strong> selecciona<strong>...  Gran Buenos Aires
# 13503  <p>Estamos buscando un  ELECTRICISTA para inco...  Gran Buenos Aires
# 13504  <p>Empresa del rubro automotor ubicada en zona...  Gran Buenos Aires
# 13505  <p>Editorial Rubinzal Culzoni, líder en el ámb...  Gran Buenos Aires
# 13506  <p>Importante empresa, se encuentra en la busq...  Gran Buenos Aires
# 13507  <p>Buscamos Programadores Oracle PL/SQL para e...  Gran Buenos Aires
# 13508  <p style="">Importante entidad con sede en Pil...  Gran Buenos Aires
# 13509  <p><em><span style="">Empresa nacional de prim...  Gran Buenos Aires
# 13510  <p align="center">Continuamos fortaleciendo nu...  Gran Buenos Aires
# 13511  <p>Seleccionaremos para empresa Metalúrgica, u...  Gran Buenos Aires
# 13512  <p>Selccionaremos Repositor/a con libreta sani...  Gran Buenos Aires
# 13513  <p style=""><span style="">Importante comercia...  Gran Buenos Aires
# 13514  <p><span style="">Para importante Logística se...  Gran Buenos Aires
# 13515  <p><strong>SOLUTIX</strong> está en búsqueda d...  Gran Buenos Aires
# 13516  <p><strong>WANDER LUBRICANTES</strong></p><p>S...    Capital Federal
# 13517  <p><span>Stefanini incorpora:</span></p><p ali...    Capital Federal
# 13518  <p>Empresa Constructora, se encuentra en la bú...  Gran Buenos Aires
# 13519  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13520  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13521  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13522  <p>Nuestro cliente, un importante PYME dedicad...  Gran Buenos Aires
# 13523  <p>UNOMOTOS Concesionaria líder en el rubro de...  Gran Buenos Aires
# 13524  <p>Importante Empresa Alimenticia, del Parque ...  Gran Buenos Aires
# 13525  <p>Importante empresa de servicios para obras ...  Gran Buenos Aires
# 13526  <p style=""><span style="">Para Importante Emp...    Capital Federal
# 13527  <p>UNOMOTOS Concesionaria líder en el rubro de...  Gran Buenos Aires
# 13528  <p><strong>RECONOCIDA EMPRESA DE MONTAJES INDU...  Gran Buenos Aires
# 13529  <p>BNP Paribas Investment Partners, importante...  Gran Buenos Aires
# 13530  <p>Somos un joven grupo gastronómico, que se e...  Gran Buenos Aires
# 13531  <p>Importante empresa de servicios para obras ...  Gran Buenos Aires
#
#                 ciudad               mapacalle tipo_de_trabajo  \
# 0                  NaN                     NaN       Full-time
# 1                  NaN                     NaN       Full-time
# 2                  NaN          Empedrado 2336       Full-time
# 3                  NaN                     NaN       Full-time
# 4                  NaN                     NaN       Full-time
# 5                  NaN                     NaN       Full-time
# 6                  NaN                     NaN       Full-time
# 7                  NaN                     NaN       Full-time
# 8         Buenos Aires                     NaN       Full-time
# 9                  NaN                     NaN       Full-time
# 10                 NaN                     NaN       Full-time
# 11                 NaN                     NaN       Full-time
# 12                 NaN                     NaN       Full-time
# 13                 NaN                     NaN       Full-time
# 14     Capital Federal                     NaN       Full-time
# 15                 NaN                     NaN       Full-time
# 16                 NaN                     NaN       Part-time
# 17                 NaN                     NaN       Full-time
# 18                 NaN                     NaN       Full-time
# 19                 NaN                     NaN       Full-time
# 20                 NaN                     NaN       Full-time
# 21                 NaN                     NaN       Full-time
# 22                 NaN                     NaN       Full-time
# 23                 NaN                     NaN       Full-time
# 24                 NaN  Gobernador Irigoyen 56       Full-time
# 25                 NaN                     NaN       Full-time
# 26                 NaN                     NaN       Full-time
# 27                 NaN                     NaN       Full-time
# 28                 NaN                     NaN       Full-time
# 29                 NaN                     NaN       Full-time
# ...                ...                     ...             ...
# 13502              NaN                     NaN       Full-time
# 13503              NaN                     NaN       Full-time
# 13504              NaN                     NaN       Full-time
# 13505              NaN                     NaN       Full-time
# 13506              NaN                     NaN       Full-time
# 13507              NaN                     NaN       Full-time
# 13508              NaN                     NaN       Full-time
# 13509              NaN                     NaN       Full-time
# 13510              NaN                     NaN       Full-time
# 13511              NaN                     NaN       Full-time
# 13512              NaN                     NaN       Full-time
# 13513              NaN                     NaN       Part-time
# 13514              NaN                     NaN       Full-time
# 13515              NaN                     NaN       Full-time
# 13516              NaN             Orsetti 700       Full-time
# 13517              NaN            Lavarden 157        Pasantia
# 13518              NaN                     NaN       Full-time
# 13519              NaN                     NaN     Teletrabajo
# 13520              NaN                     NaN     Teletrabajo
# 13521              NaN                     NaN     Teletrabajo
# 13522              NaN                     NaN       Full-time
# 13523              NaN                     NaN       Full-time
# 13524              NaN                     NaN       Full-time
# 13525              NaN                     NaN       Full-time
# 13526              NaN       Panamericana 35.7       Full-time
# 13527              NaN                     NaN       Full-time
# 13528              NaN                     NaN       Full-time
# 13529              NaN                     NaN       Full-time
# 13530              NaN                     NaN       Full-time
# 13531              NaN                     NaN       Full-time
#
#                               nivel_laboral  \
# 0                      Senior / Semi-Senior
# 1                      Senior / Semi-Senior
# 2                      Senior / Semi-Senior
# 3                      Senior / Semi-Senior
# 4                      Senior / Semi-Senior
# 5                      Senior / Semi-Senior
# 6                      Senior / Semi-Senior
# 7                                    Junior
# 8           Jefe / Supervisor / Responsable
# 9                                      Otro
# 10                     Senior / Semi-Senior
# 11                     Senior / Semi-Senior
# 12                     Senior / Semi-Senior
# 13                     Senior / Semi-Senior
# 14                     Senior / Semi-Senior
# 15                     Senior / Semi-Senior
# 16                     Senior / Semi-Senior
# 17                     Senior / Semi-Senior
# 18                     Senior / Semi-Senior
# 19                                   Junior
# 20                                   Junior
# 21                                   Junior
# 22                                     Otro
# 23                     Senior / Semi-Senior
# 24                     Senior / Semi-Senior
# 25                     Senior / Semi-Senior
# 26                     Senior / Semi-Senior
# 27                     Senior / Semi-Senior
# 28                     Senior / Semi-Senior
# 29                     Senior / Semi-Senior
# ...                                     ...
# 13502                  Senior / Semi-Senior
# 13503                  Senior / Semi-Senior
# 13504                  Senior / Semi-Senior
# 13505                  Senior / Semi-Senior
# 13506                  Senior / Semi-Senior
# 13507                  Senior / Semi-Senior
# 13508                  Senior / Semi-Senior
# 13509                  Senior / Semi-Senior
# 13510                  Senior / Semi-Senior
# 13511                  Senior / Semi-Senior
# 13512                  Senior / Semi-Senior
# 13513                  Senior / Semi-Senior
# 13514                  Senior / Semi-Senior
# 13515                                Junior
# 13516                                Junior
# 13517                                Junior
# 13518                                Junior
# 13519       Jefe / Supervisor / Responsable
# 13520       Jefe / Supervisor / Responsable
# 13521       Jefe / Supervisor / Responsable
# 13522       Jefe / Supervisor / Responsable
# 13523                  Senior / Semi-Senior
# 13524                  Senior / Semi-Senior
# 13525                  Senior / Semi-Senior
# 13526                  Senior / Semi-Senior
# 13527                  Senior / Semi-Senior
# 13528                  Senior / Semi-Senior
# 13529                                Junior
# 13530  Gerencia / Alta Gerencia / Dirección
# 13531       Jefe / Supervisor / Responsable
#
#                                  nombre_area  \
# 0                                  Comercial
# 1                                      Salud
# 2                                 Transporte
# 3                                 Transporte
# 4                                 Producción
# 5                                     Ventas
# 6                                     Ventas
# 7                                     Ventas
# 8                                  Comercial
# 9                        Atención al Cliente
# 10                                     Salud
# 11                                    Ventas
# 12                                    Ventas
# 13                             Mantenimiento
# 14                                 Comercial
# 15       Ingeniería  Eléctrica y Electrónica
# 16                                 Comercial
# 17                                    Ventas
# 18                            Abastecimiento
# 19                            Administración
# 20                              Contabilidad
# 21                              Distribución
# 22                                     Redes
# 23                                    Ventas
# 24                                 Comercial
# 25                           Soporte Técnico
# 26                                Producción
# 27                                   Calidad
# 28                                 Comercial
# 29                     Oficios y Profesiones
# ...                                      ...
# 13502                           Programación
# 13503                  Oficios y Profesiones
# 13504                  Tecnologia / Sistemas
# 13505                                 Ventas
# 13506                                  Legal
# 13507                           Programación
# 13508                     Análisis Funcional
# 13509                Compensación y Planilla
# 13510                 Ingeniería  Industrial
# 13511                             Producción
# 13512                           Distribución
# 13513                                 Ventas
# 13514                             Transporte
# 13515                           Programación
# 13516                           Contabilidad
# 13517                        Soporte Técnico
# 13518  Ingeniería Oficina Técnica / Proyecto
# 13519                  Tecnologia / Sistemas
# 13520                        Soporte Técnico
# 13521                    Atención al Cliente
# 13522                          Mantenimiento
# 13523                                 Ventas
# 13524    Compras Internacionales/Importación
# 13525                           Construcción
# 13526                                 Diseño
# 13527                                 Ventas
# 13528  Ingeniería Oficina Técnica / Proyecto
# 13529                           Contabilidad
# 13530                         Administración
# 13531                           Construcción
#
#                                 denominacion_empresa esta_online
# 0                                             VENTOR         NaN
# 1                            Farmacias Central Oeste         NaN
# 2                                        FAMITAX SRL         NaN
# 3                                Wurth Argentina S.A          si
# 4                                 ELECTRO OUTLET SRL         NaN
# 5                                Wurth Argentina S.A          si
# 6                                Wurth Argentina S.A          si
# 7                                Wurth Argentina S.A          si
# 8                  Agencia Oficial Alejandro Arizaga         NaN
# 9                                          cerantola         NaN
# 10                                 Hochschild Mining         NaN
# 11                               Wurth Argentina S.A         NaN
# 12                                        YAMANIL SA         NaN
# 13                             Adecco -Región Office          si
# 14                          Romasanta y Asociados SA         NaN
# 15                                    Bairestron SRL         NaN
# 16                                    Directway S.A.         NaN
# 17                               Wurth Argentina S.A          si
# 18                     SC Johnson & Son de Argentina         NaN
# 19                                    Unión Personal         NaN
# 20                                      Motomel S.A.         NaN
# 21                                    Asoko Tempo SA         NaN
# 22                                   TELEDIFUSORA SA          si
# 23                                      RENAULT DIAZ         NaN
# 24                                   RE/MAX TITANIUM          si
# 25                              Grupo Pujol Figueras         NaN
# 26                                            VENTOR         NaN
# 27                                      Food Service         NaN
# 28                  Nini Centro de Compras Mayorista          si
# 29                               Wurth Argentina S.A          si
# ...                                              ...         ...
# 13502                                  SOLUTIX S.A.           si
# 13503                                       Solintar          si
# 13504                               Sils Consultores          si
# 13505                             Rubinzal Editorial         NaN
# 13506                                     Suministra          si
# 13507                               Sils Consultores          si
# 13508               Soluciones y Emprendimientos SRL          si
# 13509                           Mbr Recursos Humanos          si
# 13510                               TOYOTA ARGENTINA          si
# 13511            EXTRAMEN SERVICIOS EVENTUALES S.R.L          si
# 13512                                       RANDSTAD          si
# 13513                                       precotec          si
# 13514                                         BAYTON          si
# 13515                                  SOLUTIX S.A.           si
# 13516                                Grupo Consultor          si
# 13517                        Stefanini Argentina SRL          si
# 13518                     SILVA HNOS Y RODRIGUEZ S A          si
# 13519                                      CrossOver         NaN
# 13520                                      CrossOver         NaN
# 13521                                      CrossOver         NaN
# 13522                                  VF CONSULTING         NaN
# 13523                                       UNOMOTOS          si
# 13524                                         BAYTON          si
# 13525                                      CIMA S.A.          si
# 13526                                     Cometto SA          si
# 13527                                       UNOMOTOS          si
# 13528                                Grupo Consultor          si
# 13529  BNP PARIBAS ARGENTINA INVESTMENT PARTNERS S A          si
# 13530                             Cerveteca Odin Srl          si
# 13531                                      CIMA S.A.          si
#
# [13532 rows x 12 columns]

# %%
## CHEQUEAMOS SI HAY AVISOS REPETIDOS !!
idsAviso = avisos_detalle_completo["idaviso"]
avisos_detalle_completo[idsAviso.isin(idsAviso[idsAviso.duplicated()])]
# Out:
# Empty DataFrame
# Columns: [idaviso, idpais, titulo, descripcion, nombre_zona, ciudad, mapacalle, tipo_de_trabajo, nivel_laboral, nombre_area, denominacion_empresa, esta_online]
# Index: []

# %%
avisos_detalle_completo.loc[avisos_detalle_completo.esta_online != 'si', 'esta_online'] = 'no'

# %%
avisos_detalle_completo['esta_online'].value_counts()
# Out:
# no    8819
# si    4713
# Name: esta_online, dtype: int64

# %%
avisos_detalle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
avisos_detalle_completo['nombre_area'].value_counts()
# Out:
# Ventas                                   1658
# Comercial                                 983
# Administración                            901
# Producción                                821
# Programación                              576
# Contabilidad                              415
# Tecnologia / Sistemas                     388
# Atención al Cliente                       347
# Mantenimiento                             324
# Recursos Humanos                          235
# Gastronomia                               234
# Oficios y Profesiones                     209
# Soporte Técnico                           203
# Logística                                 200
# Call Center                               191
# Almacén / Depósito / Expedición           184
# Compras                                   170
# Otros                                     153
# Marketing                                 153
# Administración de Personal                152
# Recepcionista                             151
# Transporte                                148
# Mantenimiento y Limpieza                  141
# Finanzas                                  138
# Telemarketing                             138
# Tesorería                                 137
# Créditos y Cobranzas                      132
# Salud                                     127
# Desarrollo de Negocios                    126
# Medicina                                  119
#                                          ...
# Apoderado Aduanal                           3
# Trabajo social                              2
# Topografía                                  2
# Diseño Multimedia                           2
# Educación especial                          2
# Instrumentación                             2
# Responsabilidad Social                      2
# Farmacia comercial                          2
# Otras áreas técnicas en salud               2
# Data Warehousing                            2
# Medicina Laboral                            2
# Mercadotecnia Internacional                 2
# Dirección                                   2
# Diseño 3D                                   2
# Ingeniería Geológica                        2
# Trabajo Social                              2
# Ingeniería en Petróleo y Petroquímica       1
# Bienestar Estudiantil                       1
# Instrumentación quirúrgica                  1
# Quimica                                     1
# Exploración Minera y Petroquimica           1
# Otras Especialidades médicas                1
# Comunicaciones Externas                     1
# Idiomas                                     1
# Emergentología                              1
# Traduccion                                  1
# Farmacia hospitalaria                       1
# Arte y Cultura                              1
# Urbanismo                                   1
# Telefonista                                 1
# Name: nombre_area, Length: 173, dtype: int64

# %%
avisos_detalle_completo['denominacion_empresa'].value_counts()
# Out:
# RANDSTAD                                            562
# Manpower                                            421
# Grupo Gestión                                       383
# Assistem                                            289
# SOLUTIX S.A.                                        260
# BAYTON                                              238
# Pullmen Servicios Empresarios S.A.                  229
# Adecco - Región NORTE & OESTE GBA                   205
# Suministra                                          203
# Adecco -Región Office                               200
# Consultores de Empresas SRL                         197
# Adecco -Región GBA SUR                              160
# Complement Group (holding)                          160
# Kaizen Recursos Humanos                             110
# Adecco  -Región Litoral                             109
# CrossOver                                           109
# IT Resources                                        109
# Excelencia Laboral S.A.                              98
# Swiss Medical Group                                  88
# Suple                                                88
# Aliantec                                             81
# Adecco - Región Centro Norte y Agro.                 76
# CONA CONSULTORES EN RRHH                             75
# RH Talentum                                          71
# EAYA Consulting                                      71
# Musimundo  SA                                        71
# ConfiaRH                                             63
# AB InBev - Cervecería y Maltería Quilmes             63
# BBVA Francés                                         63
# Atento                                               62
#                                                    ...
# PURECO S.R.L                                          1
# Buena Vida                                            1
# CF CONTROL SRL                                        1
# Farmacia                                              1
# Psi Consulting                                        1
# KM identidad Digital                                  1
# Fiat Giama                                            1
# Remax Arena                                           1
# FINCA SOPHENIA SA                                     1
# Mantenoa                                              1
# GEC SA                                                1
# Geller Abogados                                       1
# CASABELLA                                             1
# ESTACION DE SERVICIO SHELL DE HECTOR MARIO LUJAN      1
# WD SRL                                                1
# FF Consultores s.a.                                   1
# EDICORP                                               1
# NUVA S.A.C.I.F.I                                      1
# Clínica de la Comunidad                               1
# NTEXTIL S.A.                                          1
# Back Office                                           1
# Omnilife de Argentina                                 1
# Perfumes Córdoba                                      1
# Vileni S.R.L.                                         1
# H E ANTOLICHE S.R.L.                                  1
# A VOLAR SRL                                           1
# Nexo Consultora                                       1
# LAFE SA                                               1
# Basso Bienes Raices                                   1
# Maxxi Deportes                                        1
# Name: denominacion_empresa, Length: 2591, dtype: int64

# %%
postulaciones.info()
postulaciones.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401623 entries, 0 to 3401622
# Data columns (total 3 columns):
# idaviso             int64
# idpostulante        object
# fechapostulacion    object
# dtypes: int64(1), object(2)
# memory usage: 77.9+ MB
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
vistas_avisos.info()
vistas_avisos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961897 entries, 0 to 961896
# Data columns (total 3 columns):
# idAviso         961897 non-null int64
# timestamp       961897 non-null object
# idpostulante    961897 non-null object
# dtypes: int64(1), object(2)
# memory usage: 22.0+ MB
#       idAviso                     timestamp idpostulante
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP

# %%
vistas_avisos['fecha_vista'] = pd.to_datetime(vistas_avisos['timestamp'], errors = 'coerce')
vistas_avisos['dia_semana'] = vistas_avisos['fecha_vista'].dt.weekday_name
vistas_avisos.head()
vistas_avisos['dia_semana'].value_counts()
# Out:
# Tuesday      232145
# Monday       227957
# Wednesday    227160
# Saturday      95930
# Sunday        90646
# Friday        47236
# Thursday      40823
# Name: dia_semana, dtype: int64

# %%
postulaciones['fecha_postulado'] = postulaciones['fechapostulacion'].str.slice(0, 10)
postulaciones['fecha_postulado'] = pd.to_datetime(postulaciones['fecha_postulado'], errors = 'coerce')
postulaciones['dia_semana'] = postulaciones['fecha_postulado'].dt.weekday_name
postulaciones.head()
postulaciones['dia_semana'].value_counts()
# Out:
# Wednesday    677836
# Monday       668310
# Tuesday      658428
# Thursday     506163
# Friday       446698
# Sunday       226857
# Saturday     217331
# Name: dia_semana, dtype: int64

# %%
postulaciones_x_dias = pd.DataFrame(postulaciones['fecha_postulado'].value_counts().reset_index())
postulaciones_x_dias.columns = ['fechas','counts']
postulaciones_x_dias = postulaciones_x_dias.sort_values(by='fechas')
postulaciones_x_dias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 14 to 5
# Data columns (total 2 columns):
# fechas    45 non-null datetime64[ns]
# counts    45 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.1 KB

# %%
vistas_avisos['fechas_vista'] = vistas_avisos['timestamp'].str.slice(0, 10)
vistas_avisos['fechas_vista'] = pd.to_datetime(vistas_avisos['fechas_vista'], errors = 'coerce')

#vistas_avisos['fechas_vista'] = pd.Timestamp(vistas_avisos['timestamp']).date()
#vistas_avisos['fechas_vista'] = pd.to_datetime(vistas_avisos['timestamp'], errors = 'coerce').dt.date

avisos_x_dias = pd.DataFrame(vistas_avisos['fechas_vista'].value_counts().reset_index())
avisos_x_dias.columns = ['fechas_avisos','counts_avisos']
avisos_x_dias = avisos_x_dias.sort_values(by='fechas_avisos')
avisos_x_dias.info()
avisos_x_dias
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 5 to 2
# Data columns (total 2 columns):
# fechas_avisos    6 non-null datetime64[ns]
# counts_avisos    6 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 144.0 bytes
#   fechas_avisos  counts_avisos
# 5    2018-02-23          67747
# 4    2018-02-24          90349
# 3    2018-02-25         105245
# 0    2018-02-26         240783
# 1    2018-02-27         230947
# 2    2018-02-28         226826

# %%
#Evolucion de postulaciones a traves del tiempo vs vistas de avisos. es logico que sean correlativos pero hay solo 6 dias de datos para las vistas por lo que solo s epuede analizar una semana.

vistas_vs_postulaciones = postulaciones_x_dias.merge(avisos_x_dias,left_on='fechas', right_on='fechas_avisos',how='outer')

plt.plot( 'fechas', 'counts', data=vistas_vs_postulaciones, marker='o', markerfacecolor='blue', markersize=4, color='skyblue', linewidth=2, label = 'Postulaciones')
plt.plot( 'fechas', 'counts_avisos', data=vistas_vs_postulaciones, marker='o', color='green', markersize=4, linewidth=2, label = 'Avisos')
plt.legend()

# %%
postulaciones['dia_semana'] = pd.Categorical(postulaciones['dia_semana'], categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'], ordered=True)
postulaciones_dias = postulaciones['dia_semana'].value_counts()
postulaciones_dias = postulaciones_dias.sort_index()
postulaciones_dias
# Out:
# Monday       668310
# Tuesday      658428
# Wednesday    677836
# Thursday     506163
# Friday       446698
# Saturday     217331
# Sunday       226857
# Name: dia_semana, dtype: int64

# %%
vistas_avisos['dia_semana'] = pd.Categorical(vistas_avisos['dia_semana'], categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'], ordered=True)
vistas_avisos['dia_semana'].value_counts()
vistas_dias = vistas_avisos['dia_semana'].value_counts()
vistas_dias = vistas_dias.sort_index()
vistas_dias
# Out:
# Monday       227957
# Tuesday      232145
# Wednesday    227160
# Thursday      40823
# Friday        47236
# Saturday      95930
# Sunday        90646
# Name: dia_semana, dtype: int64

# %%
## SE SOLUCIONO EL ERROR QUE HABÍA CON EL DIA JUEVES QUE NO MARCABA DATOS

g = sns.countplot(x='dia_semana', data=vistas_avisos, order=vistas_avisos['dia_semana'].value_counts().index, orient='v')
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Dia de la semana", fontsize=15)
g.set_ylabel("Cantidad de vistas", fontsize=15)
g.set_title("Vistas por dia de la semana", fontsize=15)
# Out:
# Text(0.5,1,'Vistas por dia de la semana')

# %%
g = sns.countplot(x='dia_semana', data=postulaciones, order=postulaciones['dia_semana'].value_counts().index, orient='v')
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Dia de la semana", fontsize=15)
g.set_ylabel("Cantidad de postulaciones", fontsize=15)
g.set_title("Postulaciones por dia de la semana", fontsize=15)
# Out:
# Text(0.5,1,'Postulaciones por dia de la semana')

# %%
vistas_avisos.info()
vistas_avisos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961897 entries, 0 to 961896
# Data columns (total 5 columns):
# idAviso         961897 non-null int64
# timestamp       961897 non-null object
# idpostulante    961897 non-null object
# fecha_vista     961897 non-null datetime64[ns]
# dia_semana      961897 non-null category
# dtypes: category(1), datetime64[ns](1), int64(1), object(2)
# memory usage: 30.3+ MB
#       idAviso                     timestamp idpostulante  \
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP
#
#               fecha_vista dia_semana
# 0 2018-02-23 18:38:13.187     Friday
# 1 2018-02-23 18:38:14.296     Friday
# 2 2018-02-23 18:38:14.329     Friday
# 3 2018-02-23 18:38:17.921     Friday
# 4 2018-02-23 18:38:18.973     Friday

# %%
avisos_detalle_completo.info()
avisos_detalle_completo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13531
# Data columns (total 12 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# esta_online             13532 non-null object
# dtypes: int64(2), object(10)
# memory usage: 2.0+ MB
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa esta_online
# 0                   VENTOR          no
# 1  Farmacias Central Oeste          no
# 2              FAMITAX SRL          no
# 3      Wurth Argentina S.A          si
# 4       ELECTRO OUTLET SRL          no

# %%
vistas_avisos_completas = vistas_avisos.merge(avisos_detalle_completo,left_on='idAviso', right_on='idaviso',how='left')

# %%
vistas_avisos_completas.head()
# Out:
#       idAviso                     timestamp idpostulante  \
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP
#
#               fecha_vista dia_semana       idaviso  idpais  \
# 0 2018-02-23 18:38:13.187     Friday  1.111780e+09     1.0
# 1 2018-02-23 18:38:14.296     Friday  1.112264e+09     1.0
# 2 2018-02-23 18:38:14.329     Friday  1.112328e+09     1.0
# 3 2018-02-23 18:38:17.921     Friday  1.112319e+09     1.0
# 4 2018-02-23 18:38:18.973     Friday  1.111904e+09     1.0
#
#                                               titulo  \
# 0  OPERARIO PARA DEPOSITO, CONFECCION DE PEDIDOS,...
# 1                   Administrador Semi Senior-Linux
# 2                                  Community Manager
# 3                        Analista Jr. de Back Office
# 4                   Empleado de depósito de farmacia
#
#                                          descripcion        nombre_zona  \
# 0  <p>SE NECESITA OPERIARIO PARA DEPOSITO CONFECC...  Gran Buenos Aires
# 1  <p><strong><span style="">Stefanini IT Solutio...    Capital Federal
# 2  <p>En<strong> Adecco Tecnología </strong>proye...  Gran Buenos Aires
# 3  <p><strong>PROSEGUR,</strong> Empresa Multinac...  Gran Buenos Aires
# 4  <p> </p><div><p>Farmacias Central Oeste, empre...  Gran Buenos Aires
#
#   ciudad      mapacalle tipo_de_trabajo         nivel_laboral  \
# 0    NaN            NaN       Full-time  Senior / Semi-Senior
# 1    NaN  Santa Isabel        Full-time  Senior / Semi-Senior
# 2    NaN            NaN       Full-time  Senior / Semi-Senior
# 3    NaN            NaN       Full-time                Junior
# 4    NaN            NaN       Full-time                  Otro
#
#                   nombre_area     denominacion_empresa esta_online
# 0  Programación de producción                       dm          si
# 1             Infraestructura  Stefanini Argentina SRL          si
# 2        Community Management    Adecco -Región Office          si
# 3              Administración            Prosegur S.A.          si
# 4                Farmacéutica  Farmacias Central Oeste          si

# %%
vistas_avisos_completas['nombre_area'].fillna('-')
vistas_avisos_completas['nombre_area'].value_counts()
# Out:
# Ventas                                   128023
# Administración                           102812
# Producción                                64485
# Comercial                                 58885
# Atención al Cliente                       49203
# Recepcionista                             48756
# Call Center                               33344
# Telemarketing                             25258
# Tesorería                                 23682
# Mantenimiento y Limpieza                  23499
# Contabilidad                              19490
# Recursos Humanos                          17541
# Gastronomia                               14710
# Secretaria                                12816
# Farmacéutica                              12814
# Almacén / Depósito / Expedición           12794
# Camareros                                 12648
# Legal                                     11023
# Administración de Personal                10650
# Logística                                 10193
# Créditos y Cobranzas                       9946
# Mantenimiento                              8562
# Salud                                      8440
# Otros                                      8387
# Finanzas                                   7931
# Compras                                    7920
# Marketing                                  7751
# Transporte                                 7105
# Soporte Técnico                            7038
# Oficios y Profesiones                      6978
#                                           ...
# Creatividad                                 158
# Diseño Multimedia                           139
# Ingeniería en Minas                         138
# Emergentología                              136
# Bioquímica                                  136
# Independientes                              134
# Ingeniería de Ventas                        121
# Ingeniería en Petróleo y Petroquímica       105
# Internet                                    105
# Investigación y Desarrollo                  104
# Farmacia hospitalaria                        78
# Administración de Base de Datos              63
# Negocios Internacionales                     57
# Instrumentación                              54
# Medio Ambiente                               48
# Idiomas                                      40
# Comercio Exterior                            37
# Multimedia                                   30
# Veterinaria                                  29
# Diseño 3D                                    27
# Finanzas Internacionales                     25
# Data Warehousing                             20
# Traduccion                                   15
# Ingeniería Geológica                         14
# Dirección                                    14
# Comunicaciones Externas                      10
# Tecnico de Seguros                            8
# Exploración Minera y Petroquimica             4
# Trabajo Social                                2
# Responsabilidad Social                        1
# Name: nombre_area, Length: 160, dtype: int64

# %%
vistas_avisos_completas.loc[vistas_avisos_completas.nombre_area == 'Ingeniería  Eléctrica y Electrónica', 'nombre_area'] = 'Ingeniería Eléctrica y Electrónica'
vistas_avisos_completas.loc[vistas_avisos_completas.nombre_area == 'Ingeniería  Mecánica', 'nombre_area'] = 'Ingeniería Mecánica'
vistas_avisos_completas.loc[vistas_avisos_completas.nombre_area == 'Ingeniería  Industrial', 'nombre_area'] = 'Ingeniería Industrial'
vistas_avisos_completas.loc[vistas_avisos_completas.nombre_area == 'Ingeniería  Automotriz', 'nombre_area'] = 'Ingeniería Automotriz'
vistas_avisos_completas.loc[vistas_avisos_completas.nombre_area == 'Ingeniería  Metalurgica', 'nombre_area'] = 'Ingeniería Metalurgica'

# %%
## LIMPIAMOS LOS ACENTOS QUE NOS TRAEN PROBLEMAS A LA HORA DE GRAFICAR.
vistas_avisos_completas['nombre_area'] = vistas_avisos_completas['nombre_area'].str.replace("á", "a")
vistas_avisos_completas['nombre_area'] = vistas_avisos_completas['nombre_area'].str.replace("é", "e")
vistas_avisos_completas['nombre_area'] = vistas_avisos_completas['nombre_area'].str.replace("í", "i")
vistas_avisos_completas['nombre_area'] = vistas_avisos_completas['nombre_area'].str.replace("ó", "o")
vistas_avisos_completas['nombre_area'] = vistas_avisos_completas['nombre_area'].str.replace("ú", "u")

vistas_avisos_completas['denominacion_empresa'] = vistas_avisos_completas['denominacion_empresa'].str.replace("á", "a")
vistas_avisos_completas['denominacion_empresa'] = vistas_avisos_completas['denominacion_empresa'].str.replace("é", "e")
vistas_avisos_completas['denominacion_empresa'] = vistas_avisos_completas['denominacion_empresa'].str.replace("í", "i")
vistas_avisos_completas['denominacion_empresa'] = vistas_avisos_completas['denominacion_empresa'].str.replace("ó", "o")
vistas_avisos_completas['denominacion_empresa'] = vistas_avisos_completas['denominacion_empresa'].str.replace("ú", "u")

# %%
filtrado_ingenieria = vistas_avisos_completas[vistas_avisos_completas['nombre_area'].str.contains("Ingen", na=False)]
filtrado_ingenieria['nombre_area'] = filtrado_ingenieria['nombre_area'].str.replace("Ingenieria", "I.")
filtrado_ingenieria['nombre_area'] = filtrado_ingenieria['nombre_area'].str.replace("Ingenierias", "I.")

filtrado_ingenieria = filtrado_ingenieria[filtrado_ingenieria['nombre_area'].str.contains("I. ", na=False)]

diez_ingenierias = filtrado_ingenieria['nombre_area'].value_counts()[:10]
diez_ingenierias
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# I. Industrial                    6631
# I. Mecanica                      2618
# I. Quimica                       2383
# I. Electrica y Electronica       1844
# I. Oficina Tecnica / Proyecto    1568
# I. Civil                         1244
# I. de Procesos                   1172
# I. Electromecanica                950
# I. en Alimentos                   866
# I. Agronoma                       763
# Name: nombre_area, dtype: int64

# %%
g = sns.barplot(x= diez_ingenierias.values, y=diez_ingenierias.index)
g.set_title("TOP 10 Avisos visitados s/ rama Ingenieril", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Ingenieria en cuestion", fontsize=12)
# Out:
# Text(0,0.5,'Ingenieria en cuestion')

# %%
top_visitados_area= vistas_avisos_completas['nombre_area'].value_counts()[:10]
top_visitados_area
# Out:
# Ventas                      128023
# Administracion              102812
# Produccion                   64485
# Comercial                    58885
# Atencion al Cliente          49203
# Recepcionista                48756
# Call Center                  33344
# Telemarketing                25258
# Tesoreria                    23682
# Mantenimiento y Limpieza     23499
# Name: nombre_area, dtype: int64

# %%
g = sns.barplot(x= top_visitados_area.values, y=top_visitados_area.index)
g.set_title("TOP 10 Areas con mas visitas en sus avisos", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Area", fontsize=12)
# Out:
# Text(0,0.5,'Area')

# %%
avisos_detalle_completo.info()
avisos_detalle_completo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13531
# Data columns (total 12 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# esta_online             13532 non-null object
# dtypes: int64(2), object(10)
# memory usage: 2.0+ MB
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa esta_online
# 0                   VENTOR          no
# 1  Farmacias Central Oeste          no
# 2              FAMITAX SRL          no
# 3      Wurth Argentina S.A          si
# 4       ELECTRO OUTLET SRL          no

# %%
postulaciones.info()
postulaciones.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3401623 entries, 0 to 3401622
# Data columns (total 5 columns):
# idaviso             int64
# idpostulante        object
# fechapostulacion    object
# fecha_postulado     datetime64[ns]
# dia_semana          category
# dtypes: category(1), datetime64[ns](1), int64(1), object(2)
# memory usage: 107.1+ MB
#       idaviso idpostulante     fechapostulacion fecha_postulado dia_semana
# 0  1112257047         NM5M  2018-01-15 16:22:34      2018-01-15     Monday
# 1  1111920714         NM5M  2018-02-06 09:04:50      2018-02-06    Tuesday
# 2  1112346945         NM5M  2018-02-22 09:04:47      2018-02-22   Thursday
# 3  1112345547         NM5M  2018-02-22 09:04:59      2018-02-22   Thursday
# 4  1112237522         5awk  2018-01-25 18:55:03      2018-01-25   Thursday

# %%
postulaciones_avisos_completos = postulaciones.merge(avisos_detalle_completo,left_on='idaviso', right_on='idaviso',how='left')

# %%
## LIMPIAMOS LOS ACENTOS QUE NOS TRAEN PROBLEMAS A LA HORA DE GRAFICAR.
postulaciones_avisos_completos['nombre_area'] = postulaciones_avisos_completos['nombre_area'].str.replace("á", "a")
postulaciones_avisos_completos['nombre_area'] = postulaciones_avisos_completos['nombre_area'].str.replace("é", "e")
postulaciones_avisos_completos['nombre_area'] = postulaciones_avisos_completos['nombre_area'].str.replace("í", "i")
postulaciones_avisos_completos['nombre_area'] = postulaciones_avisos_completos['nombre_area'].str.replace("ó", "o")
postulaciones_avisos_completos['nombre_area'] = postulaciones_avisos_completos['nombre_area'].str.replace("ú", "u")

postulaciones_avisos_completos['denominacion_empresa'] = postulaciones_avisos_completos['denominacion_empresa'].str.replace("á", "a")
postulaciones_avisos_completos['denominacion_empresa'] = postulaciones_avisos_completos['denominacion_empresa'].str.replace("é", "e")
postulaciones_avisos_completos['denominacion_empresa'] = postulaciones_avisos_completos['denominacion_empresa'].str.replace("í", "i")
postulaciones_avisos_completos['denominacion_empresa'] = postulaciones_avisos_completos['denominacion_empresa'].str.replace("ó", "o")
postulaciones_avisos_completos['denominacion_empresa'] = postulaciones_avisos_completos['denominacion_empresa'].str.replace("ú", "u")

# %%
top_postulaciones_area= postulaciones_avisos_completos['nombre_area'].value_counts()[:10]
top_postulaciones_area
# Out:
# Ventas                      408148
# Administracion              291135
# Produccion                  277089
# Comercial                   216677
# Atencion al Cliente         195636
# Recepcionista               137485
# Call Center                 126430
# Telemarketing                87506
# Tesoreria                    78450
# Mantenimiento y Limpieza     63308
# Name: nombre_area, dtype: int64

# %%
g = sns.barplot(x= top_postulaciones_area.values, y=top_postulaciones_area.index)
g.set_title("TOP 10 Areas con mas postulaciones", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Area", fontsize=12)
# Out:
# Text(0,0.5,'Area')

# %%
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.nombre_area == 'Ingeniería  Eléctrica y Electrónica', 'nombre_area'] = 'Ingeniería Eléctrica y Electrónica'
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.nombre_area == 'Ingeniería  Mecánica', 'nombre_area'] = 'Ingeniería Mecánica'
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.nombre_area == 'Ingeniería  Industrial', 'nombre_area'] = 'Ingeniería Industrial'
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.nombre_area == 'Ingeniería  Automotriz', 'nombre_area'] = 'Ingeniería Automotriz'
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.nombre_area == 'Ingeniería  Metalurgica', 'nombre_area'] = 'Ingeniería Metalurgica'

# %%
filtrado_postu_ingenieria = postulaciones_avisos_completos[postulaciones_avisos_completos['nombre_area'].str.contains("Ingen", na=False)]
filtrado_postu_ingenieria['nombre_area'] = filtrado_postu_ingenieria['nombre_area'].str.replace("Ingenieria", "I.")
filtrado_postu_ingenieria['nombre_area'] = filtrado_postu_ingenieria['nombre_area'].str.replace("Ingenierias", "I.")

filtrado_postu_ingenieria = filtrado_postu_ingenieria[filtrado_postu_ingenieria['nombre_area'].str.contains("I. ", na=False)]

diez_ingenierias = filtrado_ingenieria['nombre_area'].value_counts()[:10]
diez_ingenierias
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# I. Industrial                    6631
# I. Mecanica                      2618
# I. Quimica                       2383
# I. Electrica y Electronica       1844
# I. Oficina Tecnica / Proyecto    1568
# I. Civil                         1244
# I. de Procesos                   1172
# I. Electromecanica                950
# I. en Alimentos                   866
# I. Agronoma                       763
# Name: nombre_area, dtype: int64

# %%
g = sns.barplot(x=diez_ingenierias.values, y=diez_ingenierias.index)
g.set_title("TOP 10 Areas con mas postulaciones", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Area", fontsize=12)
# Out:
# Text(0,0.5,'Area')

# %%
vistas_avisos_completas.info()
vistas_avisos_completas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961897 entries, 0 to 961896
# Data columns (total 17 columns):
# idAviso                 961897 non-null int64
# timestamp               961897 non-null object
# idpostulante            961897 non-null object
# fecha_vista             961897 non-null datetime64[ns]
# dia_semana              961897 non-null category
# idaviso                 961894 non-null float64
# idpais                  961894 non-null float64
# titulo                  961894 non-null object
# descripcion             961894 non-null object
# nombre_zona             961894 non-null object
# ciudad                  1133 non-null object
# mapacalle               67601 non-null object
# tipo_de_trabajo         961894 non-null object
# nivel_laboral           961894 non-null object
# nombre_area             961894 non-null object
# denominacion_empresa    961893 non-null object
# esta_online             961894 non-null object
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1), object(12)
# memory usage: 125.7+ MB
#       idAviso                     timestamp idpostulante  \
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP
#
#               fecha_vista dia_semana       idaviso  idpais  \
# 0 2018-02-23 18:38:13.187     Friday  1.111780e+09     1.0
# 1 2018-02-23 18:38:14.296     Friday  1.112264e+09     1.0
# 2 2018-02-23 18:38:14.329     Friday  1.112328e+09     1.0
# 3 2018-02-23 18:38:17.921     Friday  1.112319e+09     1.0
# 4 2018-02-23 18:38:18.973     Friday  1.111904e+09     1.0
#
#                                               titulo  \
# 0  OPERARIO PARA DEPOSITO, CONFECCION DE PEDIDOS,...
# 1                   Administrador Semi Senior-Linux
# 2                                  Community Manager
# 3                        Analista Jr. de Back Office
# 4                   Empleado de depósito de farmacia
#
#                                          descripcion        nombre_zona  \
# 0  <p>SE NECESITA OPERIARIO PARA DEPOSITO CONFECC...  Gran Buenos Aires
# 1  <p><strong><span style="">Stefanini IT Solutio...    Capital Federal
# 2  <p>En<strong> Adecco Tecnología </strong>proye...  Gran Buenos Aires
# 3  <p><strong>PROSEGUR,</strong> Empresa Multinac...  Gran Buenos Aires
# 4  <p> </p><div><p>Farmacias Central Oeste, empre...  Gran Buenos Aires
#
#   ciudad      mapacalle tipo_de_trabajo         nivel_laboral  \
# 0    NaN            NaN       Full-time  Senior / Semi-Senior
# 1    NaN  Santa Isabel        Full-time  Senior / Semi-Senior
# 2    NaN            NaN       Full-time  Senior / Semi-Senior
# 3    NaN            NaN       Full-time                Junior
# 4    NaN            NaN       Full-time                  Otro
#
#                   nombre_area     denominacion_empresa esta_online
# 0  Programacion de produccion                       dm          si
# 1             Infraestructura  Stefanini Argentina SRL          si
# 2        Community Management    Adecco -Region Office          si
# 3              Administracion            Prosegur S.A.          si
# 4                Farmaceutica  Farmacias Central Oeste          si

# %%
## VIENDO LOS DATOS VEMOS QUE ADECCO TIENE MUCHOS DATOS PERO SEPARADOS SEGÚN ZONAS, LOS UNIFICAMOS PARA MAYOR CLARIDAD.
vistas_avisos_completas.loc[vistas_avisos_completas.denominacion_empresa.str.contains("Adecco")==True, 'denominacion_empresa'] = 'Adecco'
vistas_avisos_completas['denominacion_empresa'].value_counts()
# Out:
# Adecco                                            68867
# Manpower                                          35692
# RANDSTAD                                          30616
# Assistem                                          25653
# Grupo Gestion                                     21395
# Pullmen Servicios Empresarios S.A.                16662
# Suministra                                        15961
# Suple                                             15744
# BAYTON                                            14683
# Consultores de Empresas SRL                       11460
# Complement Group (holding)                        10791
# Farmacity                                         10402
# BBVA Frances                                       8275
# Swiss Medical Group                                7742
# BANCO MACRO                                        7095
# Union Personal                                     7093
# Grupo Teleperformance                              7049
# Asoko Tempo SA                                     7037
# RH Talentum                                        6849
# EAYA Consulting                                    6248
# Deloitte                                           5870
# HuCap                                              5857
# Fundacion Favaloro                                 5684
# Food Service                                       5497
# AB InBev - Cerveceria y Malteria Quilmes           5301
# Garbarino                                          5091
# CONA CONSULTORES EN RRHH                           4943
# Banco Columbia SA                                  4837
# Excelencia Laboral S.A.                            4795
# Grupo Cosmos                                       4680
#                                                   ...
# MUU LECHERÍA                                          1
# YAMANIL SA                                            1
# Los Azu                                               1
# wrangler                                              1
# TUTEUR                                                1
# COTISHOP SOCIEDAD ANONIMA                             1
# Weber & Asociados                                     1
# LOMA NEGRA C.I.A.S.A.                                 1
# ADN Merchandising                                     1
# Medical Web Experts                                   1
# Berlim                                                1
# Importante Empresa Gastronomica                       1
# LAFE SA                                               1
# Centralab  S.A                                        1
# CODYLSA                                               1
# Importadora Bs As                                     1
# BOART LONGYEAR ARGENTINA SA                           1
# Casa Hospital San Juan de Dios  - Ramos Mejia         1
# Administradora de Monederos Electronicos S.A.         1
# GENCO Comercio Exterior                               1
# La Caja de Ahorro y Seguros S.A.                      1
# Betos Lomitos                                         1
# DUDU HR                                               1
# ARROW SERVICIOS S.R.L                                 1
# Consentio Strategic Partners                          1
# silvia b. elias                                       1
# CREDITIA S.A.                                         1
# Master Health                                         1
# Cecilia Demadonna RRHH                                1
# AUTOGEN S.A.                                          1
# Name: denominacion_empresa, Length: 1822, dtype: int64

# %%
denominacion_filtro = vistas_avisos_completas[vistas_avisos_completas.denominacion_empresa.str.contains("Medic")==True]
denominacion_filtro['denominacion_empresa'].value_counts()
# Out:
# Swiss Medical Group                                           7742
# Alexander Fleming Instituto Medico Especializado              2465
# Medical Hair Instituto de Implantes y Medicina Capilar SRL    1875
# Agencia Medica                                                 213
# Nipro Medical Corporation                                      153
# Medical System S.A                                              64
# IRT (Razon social: Medicina para Empresas S.A.)                 18
# IPC Instituto Medico                                             6
# Bristol Medicine S.R.L.                                          5
# Medical Web Experts                                              1
# Name: denominacion_empresa, dtype: int64

# %%
diez_vistas_empresas = vistas_avisos_completas['denominacion_empresa'].value_counts()[:10]
diez_vistas_empresas
# Out:
# Adecco                                68867
# Manpower                              35692
# RANDSTAD                              30616
# Assistem                              25653
# Grupo Gestion                         21395
# Pullmen Servicios Empresarios S.A.    16662
# Suministra                            15961
# Suple                                 15744
# BAYTON                                14683
# Consultores de Empresas SRL           11460
# Name: denominacion_empresa, dtype: int64

# %%
g = sns.barplot(x=diez_vistas_empresas.values, y=diez_vistas_empresas.index)
g.set_title("TOP 10 con mas visitas a sus avisos", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Nombre de empresa", fontsize=12)
# Out:
# Text(0,0.5,'Nombre de empresa')

# %%
## VIENDO LOS DATOS VEMOS QUE ADECCO TIENE MUCHOS DATOS PERO SEPARADOS SEGÚN ZONAS, LOS UNIFICAMOS PARA MAYOR CLARIDAD.
postulaciones_avisos_completos.loc[postulaciones_avisos_completos.denominacion_empresa.str.contains("Adecco")==True, 'denominacion_empresa'] = 'Adecco'
postulaciones_avisos_completos['denominacion_empresa'].value_counts()
# Out:
# Adecco                                             238052
# Manpower                                           119013
# RANDSTAD                                           102640
# Grupo Gestion                                       89950
# Assistem                                            68125
# Farmacity                                           57583
# BAYTON                                              55048
# BBVA Frances                                        54805
# Pullmen Servicios Empresarios S.A.                  51471
# Suministra                                          42843
# Suple                                               35317
# Complement Group (holding)                          32923
# Asoko Tempo SA                                      26853
# HuCap                                               23330
# Consultores de Empresas SRL                         22856
# Swiss Medical Group                                 22025
# Musimundo  SA                                       21314
# Excelencia Laboral S.A.                             21118
# Grupo Cosmos                                        20882
# COTO cicsa                                          20637
# Union Personal                                      19813
# CONA CONSULTORES EN RRHH                            18548
# RH Talentum                                         18176
# Fundacion Favaloro                                  17352
# EAYA Consulting                                     16221
# Atento                                              16024
# Garbarino                                           14488
# Baires Select RRHH SRL                              14332
# Prosegur S.A.                                       14150
# BANCO MACRO                                         13961
#                                                     ...
# IT+ SA                                                  3
# Pulars SA                                               3
# IRT (Razon social: Medicina para Empresas S.A.)         3
# Occhiuzzi Diagnostico Medico                            3
# TELESCOPE SERVICES AB                                   3
# Importante Centro de Estetica y Peluqueria              3
# Grupo Pomiglio                                          3
# Timesolution                                            3
# AMOBA                                                   3
# CDR RRHH                                                2
# Romasanta y Asociados SA                                2
# GEDCO                                                   2
# 1974                                                    2
# Autotransporte Presidente Alvear                        2
# TALLER TECHNOLOGIES S.A.                                2
# Veronica                                                2
# FAST TRACK                                              2
# CLASS Möbel                                             2
# S PAS Nav                                               2
# SIAR INDUSTRIAL SRL                                     2
# Atene Logistic                                          1
# Pharma Quality Europe                                   1
# MindHub                                                 1
# Smart City Solutions SA                                 1
# Telescope Services                                      1
# SANATORIO DE LA PROVIDENCIA                             1
# FLOWING CODE S.A.                                       1
# In Your Head SRL                                        1
# SitioLinks                                              1
# DAS Consultora                                          1
# Name: denominacion_empresa, Length: 2203, dtype: int64

# %%
diez_postulaciones_empresas = postulaciones_avisos_completos['denominacion_empresa'].value_counts()[:10]
diez_postulaciones_empresas
# Out:
# Adecco                                238052
# Manpower                              119013
# RANDSTAD                              102640
# Grupo Gestion                          89950
# Assistem                               68125
# Farmacity                              57583
# BAYTON                                 55048
# BBVA Frances                           54805
# Pullmen Servicios Empresarios S.A.     51471
# Suministra                             42843
# Name: denominacion_empresa, dtype: int64

# %%
g = sns.barplot(x=diez_postulaciones_empresas.values, y=diez_postulaciones_empresas.index)
g.set_title("TOP 10 con mas visitas a sus avisos", fontsize=15)
g.set_xlabel("Cantidad de visitas", fontsize=12)
g.set_ylabel("Nombre de empresa", fontsize=12)
# Out:
# Text(0,0.5,'Nombre de empresa')

# %%
avisos_detalle.info()
avisos_detalle.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13532 entries, 0 to 13533
# Data columns (total 11 columns):
# idaviso                 13532 non-null int64
# idpais                  13532 non-null int64
# titulo                  13532 non-null object
# descripcion             13532 non-null object
# nombre_zona             13532 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13532 non-null object
# nivel_laboral           13532 non-null object
# nombre_area             13532 non-null object
# denominacion_empresa    13527 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa
# 0                   VENTOR
# 1  Farmacias Central Oeste
# 2              FAMITAX SRL
# 3      Wurth Argentina S.A
# 4       ELECTRO OUTLET SRL

# %%
vistas_avisos_completas.info()
vistas_avisos_completas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961897 entries, 0 to 961896
# Data columns (total 17 columns):
# idAviso                 961897 non-null int64
# timestamp               961897 non-null object
# idpostulante            961897 non-null object
# fecha_vista             961897 non-null datetime64[ns]
# dia_semana              961897 non-null category
# idaviso                 961894 non-null float64
# idpais                  961894 non-null float64
# titulo                  961894 non-null object
# descripcion             961894 non-null object
# nombre_zona             961894 non-null object
# ciudad                  1133 non-null object
# mapacalle               67601 non-null object
# tipo_de_trabajo         961894 non-null object
# nivel_laboral           961894 non-null object
# nombre_area             961894 non-null object
# denominacion_empresa    961893 non-null object
# esta_online             961894 non-null object
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1), object(12)
# memory usage: 125.7+ MB
#       idAviso                     timestamp idpostulante  \
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP
#
#               fecha_vista dia_semana       idaviso  idpais  \
# 0 2018-02-23 18:38:13.187     Friday  1.111780e+09     1.0
# 1 2018-02-23 18:38:14.296     Friday  1.112264e+09     1.0
# 2 2018-02-23 18:38:14.329     Friday  1.112328e+09     1.0
# 3 2018-02-23 18:38:17.921     Friday  1.112319e+09     1.0
# 4 2018-02-23 18:38:18.973     Friday  1.111904e+09     1.0
#
#                                               titulo  \
# 0  OPERARIO PARA DEPOSITO, CONFECCION DE PEDIDOS,...
# 1                   Administrador Semi Senior-Linux
# 2                                  Community Manager
# 3                        Analista Jr. de Back Office
# 4                   Empleado de depósito de farmacia
#
#                                          descripcion        nombre_zona  \
# 0  <p>SE NECESITA OPERIARIO PARA DEPOSITO CONFECC...  Gran Buenos Aires
# 1  <p><strong><span style="">Stefanini IT Solutio...    Capital Federal
# 2  <p>En<strong> Adecco Tecnología </strong>proye...  Gran Buenos Aires
# 3  <p><strong>PROSEGUR,</strong> Empresa Multinac...  Gran Buenos Aires
# 4  <p> </p><div><p>Farmacias Central Oeste, empre...  Gran Buenos Aires
#
#   ciudad      mapacalle tipo_de_trabajo         nivel_laboral  \
# 0    NaN            NaN       Full-time  Senior / Semi-Senior
# 1    NaN  Santa Isabel        Full-time  Senior / Semi-Senior
# 2    NaN            NaN       Full-time  Senior / Semi-Senior
# 3    NaN            NaN       Full-time                Junior
# 4    NaN            NaN       Full-time                  Otro
#
#                   nombre_area     denominacion_empresa esta_online
# 0  Programacion de produccion                       dm          si
# 1             Infraestructura  Stefanini Argentina SRL          si
# 2        Community Management                   Adecco          si
# 3              Administracion            Prosegur S.A.          si
# 4                Farmaceutica  Farmacias Central Oeste          si

# %%
vistas_avisos_completas['fecha_vista_completa'] = pd.to_datetime(vistas_avisos_completas['timestamp'], errors = 'coerce')

# %%
vistas_avisos_completas['dia_semana_completa'] = vistas_avisos_completas['fecha_vista_completa'].dt.weekday_name

# %%
vistas_avisos_completas['dia_semana_completa'].value_counts()
# Out:
# Tuesday      232145
# Monday       227957
# Wednesday    227160
# Saturday      95930
# Sunday        90646
# Friday        47236
# Thursday      40823
# Name: dia_semana_completa, dtype: int64

# %%
vistas_avisos_completas['mes_completa'] = vistas_avisos_completas['fecha_vista_completa'].dt.month
vistas_avisos_completas['mes_completa'].value_counts()
# Out:
# 2    921074
# 3     40823
# Name: mes_completa, dtype: int64

# %%
vistas_avisos_completas['dia_completa'] = vistas_avisos_completas['fecha_vista_completa'].dt.day
vistas_avisos_completas['dia_completa'].value_counts()
# Out:
# 27    232145
# 26    227957
# 28    227160
# 24     95930
# 25     90646
# 23     47236
# 1      40823
# Name: dia_completa, dtype: int64

# %%
## g = sns.factorplot(x="sex", y="total_bill", hue="smoker", col="time", data=tips, kind="swarm", size=4, aspect=.7);
## postulantes_unicos
vistas_avisos_completas.info()

vistas_avisos_completas = vistas_avisos_completas.merge(postulantes_unicos,left_on='idpostulante', right_on='idpostulante',how='left')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961897 entries, 0 to 961896
# Data columns (total 21 columns):
# idAviso                 961897 non-null int64
# timestamp               961897 non-null object
# idpostulante            961897 non-null object
# fecha_vista             961897 non-null datetime64[ns]
# dia_semana              961897 non-null category
# idaviso                 961894 non-null float64
# idpais                  961894 non-null float64
# titulo                  961894 non-null object
# descripcion             961894 non-null object
# nombre_zona             961894 non-null object
# ciudad                  1133 non-null object
# mapacalle               67601 non-null object
# tipo_de_trabajo         961894 non-null object
# nivel_laboral           961894 non-null object
# nombre_area             961894 non-null object
# denominacion_empresa    961893 non-null object
# esta_online             961894 non-null object
# fecha_vista_completa    961897 non-null datetime64[ns]
# dia_semana_completa     961897 non-null object
# mes_completa            961897 non-null int64
# dia_completa            961897 non-null int64
# dtypes: category(1), datetime64[ns](2), float64(2), int64(3), object(13)
# memory usage: 155.0+ MB

# %%
vistas_avisos_completas.info()
vistas_avisos_completas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961897 entries, 0 to 961896
# Data columns (total 28 columns):
# idAviso                 961897 non-null int64
# timestamp               961897 non-null object
# idpostulante            961897 non-null object
# fecha_vista             961897 non-null datetime64[ns]
# dia_semana              961897 non-null category
# idaviso                 961894 non-null float64
# idpais                  961894 non-null float64
# titulo                  961894 non-null object
# descripcion             961894 non-null object
# nombre_zona             961894 non-null object
# ciudad                  1133 non-null object
# mapacalle               67601 non-null object
# tipo_de_trabajo         961894 non-null object
# nivel_laboral           961894 non-null object
# nombre_area             961894 non-null object
# denominacion_empresa    961893 non-null object
# esta_online             961894 non-null object
# fecha_vista_completa    961897 non-null datetime64[ns]
# dia_semana_completa     961897 non-null object
# mes_completa            961897 non-null int64
# dia_completa            961897 non-null int64
# nombre                  894925 non-null object
# estado                  894925 non-null object
# fechanacimiento         938523 non-null datetime64[ns]
# sexo                    938523 non-null object
# tamañoFecha             938523 non-null float64
# edad                    938523 non-null float64
# rango_edad              938523 non-null object
# dtypes: category(1), datetime64[ns](3), float64(4), int64(3), object(17)
# memory usage: 206.4+ MB
#       idAviso                     timestamp idpostulante  \
# 0  1111780242  2018-02-23T13:38:13.187-0500      YjVJQ6Z
# 1  1112263876  2018-02-23T13:38:14.296-0500      BmVpYoR
# 2  1112327963  2018-02-23T13:38:14.329-0500      wVkBzZd
# 3  1112318643  2018-02-23T13:38:17.921-0500      OqmP9pv
# 4  1111903673  2018-02-23T13:38:18.973-0500      DrpbXDP
#
#               fecha_vista dia_semana       idaviso  idpais  \
# 0 2018-02-23 18:38:13.187     Friday  1.111780e+09     1.0
# 1 2018-02-23 18:38:14.296     Friday  1.112264e+09     1.0
# 2 2018-02-23 18:38:14.329     Friday  1.112328e+09     1.0
# 3 2018-02-23 18:38:17.921     Friday  1.112319e+09     1.0
# 4 2018-02-23 18:38:18.973     Friday  1.111904e+09     1.0
#
#                                               titulo  \
# 0  OPERARIO PARA DEPOSITO, CONFECCION DE PEDIDOS,...
# 1                   Administrador Semi Senior-Linux
# 2                                  Community Manager
# 3                        Analista Jr. de Back Office
# 4                   Empleado de depósito de farmacia
#
#                                          descripcion        nombre_zona  \
# 0  <p>SE NECESITA OPERIARIO PARA DEPOSITO CONFECC...  Gran Buenos Aires
# 1  <p><strong><span style="">Stefanini IT Solutio...    Capital Federal
# 2  <p>En<strong> Adecco Tecnología </strong>proye...  Gran Buenos Aires
# 3  <p><strong>PROSEGUR,</strong> Empresa Multinac...  Gran Buenos Aires
# 4  <p> </p><div><p>Farmacias Central Oeste, empre...  Gran Buenos Aires
#
#       ...     dia_semana_completa mes_completa dia_completa         nombre  \
# 0     ...                  Friday            2           23     Secundario
# 1     ...                  Friday            2           23  Universitario
# 2     ...                  Friday            2           23  Universitario
# 3     ...                  Friday            2           23  Universitario
# 4     ...                  Friday            2           23     Secundario
#
#      estado fechanacimiento  sexo tamañoFecha  edad  rango_edad
# 0  Graduado      1991-11-16  MASC        10.0  26.0     25 ~ 30
# 1  En Curso      1989-12-08  MASC        10.0  28.0     25 ~ 30
# 2  En Curso      1992-10-06  MASC        10.0  25.0     25 ~ 30
# 3  En Curso      1993-10-17  MASC        10.0  24.0     20 ~ 25
# 4  Graduado      1991-08-01  MASC        10.0  26.0     25 ~ 30
#
# [5 rows x 28 columns]

# %%
info_postulantes = vistas_avisos_completas.groupby(['idpostulante', 'sexo','esta_online']).size().reset_index(name='counts')

# %%
g = sns.factorplot(x="sexo", y="counts", hue="esta_online", data=info_postulantes, kind="strip", jitter=True, size=10, aspect=.7);

# %%
info_postulantes = info_postulantes[info_postulantes['counts'] < 300]

# %%
g = sns.factorplot(x="sexo", y="counts", hue="esta_online", data=info_postulantes, kind="strip", jitter=True, size=10, aspect=.9);

# %%
postulaciones_avisos_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3401623 entries, 0 to 3401622
# Data columns (total 16 columns):
# idaviso                 int64
# idpostulante            object
# fechapostulacion        object
# fecha_postulado         datetime64[ns]
# dia_semana              category
# idpais                  float64
# titulo                  object
# descripcion             object
# nombre_zona             object
# ciudad                  object
# mapacalle               object
# tipo_de_trabajo         object
# nivel_laboral           object
# nombre_area             object
# denominacion_empresa    object
# esta_online             object
# dtypes: category(1), datetime64[ns](1), float64(1), int64(1), object(12)
# memory usage: 418.5+ MB

# %%
## g = sns.stripplot(x="total_bill", y="day", data=tips, jitter=True, linewidth=1)
postulaciones_avisos_completos = postulaciones_avisos_completos.merge(postulantes_unicos,left_on='idpostulante', right_on='idpostulante',how='left')
info_postulantes = postulaciones_avisos_completos.groupby(['idpostulante', 'sexo','esta_online']).size().reset_index(name='cantidad')

# %%
g = sns.factorplot(x="sexo", y="cantidad", hue="esta_online", data=info_postulantes, kind="strip", jitter=True, size=10, aspect=.9);

# %%
info_postulantes = info_postulantes[info_postulantes['cantidad'] < 750]

# %%
g = sns.factorplot(x="sexo", y="cantidad", hue="esta_online", data=info_postulantes, kind="strip", jitter=True, size=10, aspect=.9);

# %%
vistas_online = vistas_avisos_completas[vistas_avisos_completas['esta_online'] == 'si']
vistas_offline = vistas_avisos_completas[vistas_avisos_completas['esta_online'] != 'si']

# %%
sizes = [vistas_online.esta_online.count(), vistas_offline.esta_online.count()]
nombres = ['Online', 'Offline']

plt.figure(figsize=(6, 6))
plt.title('Distribucion sobre las visitas a los avisos online/offline', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['lightgreen', 'lightblue'], explode=(0.1, 0))
plt.show()

# %%
postulaciones_online = postulaciones_avisos_completos[postulaciones_avisos_completos['esta_online'] == 'si']
postulaciones_offline = postulaciones_avisos_completos[postulaciones_avisos_completos['esta_online'] != 'si']

# %%
sizes = [postulaciones_online.esta_online.count(), postulaciones_offline.esta_online.count()]
nombres = ['Online', 'Offline']

plt.figure(figsize=(6, 6))
plt.title('Distribucion sobre las visitas a los avisos online/offline', fontsize=20)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['lightgreen', 'lightblue'], explode=(0.1, 0))
plt.show()
